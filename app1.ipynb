# %%
import pandas as pd
df = pd.read_csv(
    "C:\\Users\\pc\\Desktop\\Data science & AI\\Data science\\Python\\csv\\Project_Data.csv")

df
# Out:
#     sprintId   sprintName.keyword      projectName.keyword sprintStartDate  \
# 0      1,426         EPP Sprint 9  Eurisko Platform Portal       8/14/2023
# 1      1,426         EPP Sprint 9  Eurisko Platform Portal       8/14/2023
# 2      1,426         EPP Sprint 9  Eurisko Platform Portal       8/14/2023
# 3      1,426         EPP Sprint 9  Eurisko Platform Portal       8/14/2023
# 4      1,426         EPP Sprint 9  Eurisko Platform Portal       8/14/2023
# ..       ...                  ...                      ...             ...
# 486    1,363  HIVERSE - Sprint 77                  Hiverse       6/21/2023
# 487    1,363  HIVERSE - Sprint 77                  Hiverse       6/21/2023
# 488    1,363  HIVERSE - Sprint 77                  Hiverse       6/21/2023
# 489    1,363  HIVERSE - Sprint 77                  Hiverse       6/21/2023
# 490    1,363  HIVERSE - Sprint 77                  Hiverse       6/21/2023
#
#     sprintEndDate  storyPoints storyKey.keyword sprintDurationPassed  \
# 0       8/21/2023           13          EPP-111              612,001
# 1       8/21/2023            8          EPP-138              612,001
# 2       8/21/2023           13          EPP-107              626,402
# 3       8/21/2023           13          EPP-134              626,402
# 4       8/21/2023           13          EPP-133              626,402
# ..            ...          ...              ...                  ...
# 486      7/5/2023            0     HIVERSE-9512            5,864,405
# 487      7/5/2023            0     HIVERSE-9526            5,864,405
# 488      7/5/2023            0     HIVERSE-9551            5,864,405
# 489      7/5/2023            0     HIVERSE-9777            5,864,405
# 490      7/5/2023            0     HIVERSE-9778            5,864,405
#
#     sprintDurationEstimated parentKey parentId              projectName  \
# 0                   604,800         -        -  Eurisko Platform Portal
# 1                   604,800         -        -  Eurisko Platform Portal
# 2                   604,800         -        -  Eurisko Platform Portal
# 3                   604,800         -        -  Eurisko Platform Portal
# 4                   604,800         -        -  Eurisko Platform Portal
# ..                      ...       ...      ...                      ...
# 486               1,209,600         -        -                  Hiverse
# 487               1,209,600         -        -                  Hiverse
# 488               1,209,600         -        -                  Hiverse
# 489               1,209,600         -        -                  Hiverse
# 490               1,209,600         -        -                  Hiverse
#
#               sprintName sprintStatus      storyKey  isSubTask storyType  \
# 0           EPP Sprint 9       active       EPP-111      False     Story
# 1           EPP Sprint 9       active       EPP-138      False      Task
# 2           EPP Sprint 9       active       EPP-107      False     Story
# 3           EPP Sprint 9       active       EPP-134      False     Story
# 4           EPP Sprint 9       active       EPP-133      False     Story
# ..                   ...          ...           ...        ...       ...
# 486  HIVERSE - Sprint 77       active  HIVERSE-9512      False       Bug
# 487  HIVERSE - Sprint 77       active  HIVERSE-9526      False       Bug
# 488  HIVERSE - Sprint 77       active  HIVERSE-9551      False       Bug
# 489  HIVERSE - Sprint 77       active  HIVERSE-9777      False       Bug
# 490  HIVERSE - Sprint 77       active  HIVERSE-9778      False       Bug
#
#     timeSpent storyStatus
# 0           0       To Do
# 1           0       To Do
# 2       7,200        Done
# 3           0        Done
# 4      50,400        Done
# ..        ...         ...
# 486         0        Done
# 487       600        Done
# 488         0        Done
# 489       600        Done
# 490         0        Done
#
# [491 rows x 19 columns]

# %%
df.drop({'projectName',"sprintName","storyKey.keyword" }, axis=1, inplace=True)

# %%
df
# Out:
#     sprintId   sprintName.keyword      projectName.keyword sprintStartDate  \
# 0      1,426         EPP Sprint 9  Eurisko Platform Portal       8/14/2023
# 1      1,426         EPP Sprint 9  Eurisko Platform Portal       8/14/2023
# 2      1,426         EPP Sprint 9  Eurisko Platform Portal       8/14/2023
# 3      1,426         EPP Sprint 9  Eurisko Platform Portal       8/14/2023
# 4      1,426         EPP Sprint 9  Eurisko Platform Portal       8/14/2023
# ..       ...                  ...                      ...             ...
# 486    1,363  HIVERSE - Sprint 77                  Hiverse       6/21/2023
# 487    1,363  HIVERSE - Sprint 77                  Hiverse       6/21/2023
# 488    1,363  HIVERSE - Sprint 77                  Hiverse       6/21/2023
# 489    1,363  HIVERSE - Sprint 77                  Hiverse       6/21/2023
# 490    1,363  HIVERSE - Sprint 77                  Hiverse       6/21/2023
#
#     sprintEndDate  storyPoints sprintDurationPassed sprintDurationEstimated  \
# 0       8/21/2023           13              612,001                 604,800
# 1       8/21/2023            8              612,001                 604,800
# 2       8/21/2023           13              626,402                 604,800
# 3       8/21/2023           13              626,402                 604,800
# 4       8/21/2023           13              626,402                 604,800
# ..            ...          ...                  ...                     ...
# 486      7/5/2023            0            5,864,405               1,209,600
# 487      7/5/2023            0            5,864,405               1,209,600
# 488      7/5/2023            0            5,864,405               1,209,600
# 489      7/5/2023            0            5,864,405               1,209,600
# 490      7/5/2023            0            5,864,405               1,209,600
#
#     parentKey parentId sprintStatus      storyKey  isSubTask storyType  \
# 0           -        -       active       EPP-111      False     Story
# 1           -        -       active       EPP-138      False      Task
# 2           -        -       active       EPP-107      False     Story
# 3           -        -       active       EPP-134      False     Story
# 4           -        -       active       EPP-133      False     Story
# ..        ...      ...          ...           ...        ...       ...
# 486         -        -       active  HIVERSE-9512      False       Bug
# 487         -        -       active  HIVERSE-9526      False       Bug
# 488         -        -       active  HIVERSE-9551      False       Bug
# 489         -        -       active  HIVERSE-9777      False       Bug
# 490         -        -       active  HIVERSE-9778      False       Bug
#
#     timeSpent storyStatus
# 0           0       To Do
# 1           0       To Do
# 2       7,200        Done
# 3           0        Done
# 4      50,400        Done
# ..        ...         ...
# 486         0        Done
# 487       600        Done
# 488         0        Done
# 489       600        Done
# 490         0        Done
#
# [491 rows x 16 columns]

# %%
df.rename(columns={'sprintName.keyword': 'sprintName', 'projectName.keyword': 'projectName'}, inplace=True)

# %%
df
# Out:
#     sprintId           sprintName              projectName sprintStartDate  \
# 0      1,426         EPP Sprint 9  Eurisko Platform Portal       8/14/2023
# 1      1,426         EPP Sprint 9  Eurisko Platform Portal       8/14/2023
# 2      1,426         EPP Sprint 9  Eurisko Platform Portal       8/14/2023
# 3      1,426         EPP Sprint 9  Eurisko Platform Portal       8/14/2023
# 4      1,426         EPP Sprint 9  Eurisko Platform Portal       8/14/2023
# ..       ...                  ...                      ...             ...
# 486    1,363  HIVERSE - Sprint 77                  Hiverse       6/21/2023
# 487    1,363  HIVERSE - Sprint 77                  Hiverse       6/21/2023
# 488    1,363  HIVERSE - Sprint 77                  Hiverse       6/21/2023
# 489    1,363  HIVERSE - Sprint 77                  Hiverse       6/21/2023
# 490    1,363  HIVERSE - Sprint 77                  Hiverse       6/21/2023
#
#     sprintEndDate  storyPoints sprintDurationPassed sprintDurationEstimated  \
# 0       8/21/2023           13              612,001                 604,800
# 1       8/21/2023            8              612,001                 604,800
# 2       8/21/2023           13              626,402                 604,800
# 3       8/21/2023           13              626,402                 604,800
# 4       8/21/2023           13              626,402                 604,800
# ..            ...          ...                  ...                     ...
# 486      7/5/2023            0            5,864,405               1,209,600
# 487      7/5/2023            0            5,864,405               1,209,600
# 488      7/5/2023            0            5,864,405               1,209,600
# 489      7/5/2023            0            5,864,405               1,209,600
# 490      7/5/2023            0            5,864,405               1,209,600
#
#     parentKey parentId sprintStatus      storyKey  isSubTask storyType  \
# 0           -        -       active       EPP-111      False     Story
# 1           -        -       active       EPP-138      False      Task
# 2           -        -       active       EPP-107      False     Story
# 3           -        -       active       EPP-134      False     Story
# 4           -        -       active       EPP-133      False     Story
# ..        ...      ...          ...           ...        ...       ...
# 486         -        -       active  HIVERSE-9512      False       Bug
# 487         -        -       active  HIVERSE-9526      False       Bug
# 488         -        -       active  HIVERSE-9551      False       Bug
# 489         -        -       active  HIVERSE-9777      False       Bug
# 490         -        -       active  HIVERSE-9778      False       Bug
#
#     timeSpent storyStatus
# 0           0       To Do
# 1           0       To Do
# 2       7,200        Done
# 3           0        Done
# 4      50,400        Done
# ..        ...         ...
# 486         0        Done
# 487       600        Done
# 488         0        Done
# 489       600        Done
# 490         0        Done
#
# [491 rows x 16 columns]

# %%
df1 = df.copy()

# %%
df1
# Out:
#     sprintId           sprintName              projectName sprintStartDate  \
# 0      1,426         EPP Sprint 9  Eurisko Platform Portal       8/14/2023
# 1      1,426         EPP Sprint 9  Eurisko Platform Portal       8/14/2023
# 2      1,426         EPP Sprint 9  Eurisko Platform Portal       8/14/2023
# 3      1,426         EPP Sprint 9  Eurisko Platform Portal       8/14/2023
# 4      1,426         EPP Sprint 9  Eurisko Platform Portal       8/14/2023
# ..       ...                  ...                      ...             ...
# 486    1,363  HIVERSE - Sprint 77                  Hiverse       6/21/2023
# 487    1,363  HIVERSE - Sprint 77                  Hiverse       6/21/2023
# 488    1,363  HIVERSE - Sprint 77                  Hiverse       6/21/2023
# 489    1,363  HIVERSE - Sprint 77                  Hiverse       6/21/2023
# 490    1,363  HIVERSE - Sprint 77                  Hiverse       6/21/2023
#
#     sprintEndDate  storyPoints sprintDurationPassed sprintDurationEstimated  \
# 0       8/21/2023           13              612,001                 604,800
# 1       8/21/2023            8              612,001                 604,800
# 2       8/21/2023           13              626,402                 604,800
# 3       8/21/2023           13              626,402                 604,800
# 4       8/21/2023           13              626,402                 604,800
# ..            ...          ...                  ...                     ...
# 486      7/5/2023            0            5,864,405               1,209,600
# 487      7/5/2023            0            5,864,405               1,209,600
# 488      7/5/2023            0            5,864,405               1,209,600
# 489      7/5/2023            0            5,864,405               1,209,600
# 490      7/5/2023            0            5,864,405               1,209,600
#
#     parentKey parentId sprintStatus      storyKey  isSubTask storyType  \
# 0           -        -       active       EPP-111      False     Story
# 1           -        -       active       EPP-138      False      Task
# 2           -        -       active       EPP-107      False     Story
# 3           -        -       active       EPP-134      False     Story
# 4           -        -       active       EPP-133      False     Story
# ..        ...      ...          ...           ...        ...       ...
# 486         -        -       active  HIVERSE-9512      False       Bug
# 487         -        -       active  HIVERSE-9526      False       Bug
# 488         -        -       active  HIVERSE-9551      False       Bug
# 489         -        -       active  HIVERSE-9777      False       Bug
# 490         -        -       active  HIVERSE-9778      False       Bug
#
#     timeSpent storyStatus
# 0           0       To Do
# 1           0       To Do
# 2       7,200        Done
# 3           0        Done
# 4      50,400        Done
# ..        ...         ...
# 486         0        Done
# 487       600        Done
# 488         0        Done
# 489       600        Done
# 490         0        Done
#
# [491 rows x 16 columns]

# %%
df1["sprintStartDate"] = pd.to_datetime(df1['sprintStartDate'])

# %%
df1
# Out:
#     sprintId           sprintName              projectName sprintStartDate  \
# 0      1,426         EPP Sprint 9  Eurisko Platform Portal      2023-08-14
# 1      1,426         EPP Sprint 9  Eurisko Platform Portal      2023-08-14
# 2      1,426         EPP Sprint 9  Eurisko Platform Portal      2023-08-14
# 3      1,426         EPP Sprint 9  Eurisko Platform Portal      2023-08-14
# 4      1,426         EPP Sprint 9  Eurisko Platform Portal      2023-08-14
# ..       ...                  ...                      ...             ...
# 486    1,363  HIVERSE - Sprint 77                  Hiverse      2023-06-21
# 487    1,363  HIVERSE - Sprint 77                  Hiverse      2023-06-21
# 488    1,363  HIVERSE - Sprint 77                  Hiverse      2023-06-21
# 489    1,363  HIVERSE - Sprint 77                  Hiverse      2023-06-21
# 490    1,363  HIVERSE - Sprint 77                  Hiverse      2023-06-21
#
#     sprintEndDate  storyPoints sprintDurationPassed sprintDurationEstimated  \
# 0       8/21/2023           13              612,001                 604,800
# 1       8/21/2023            8              612,001                 604,800
# 2       8/21/2023           13              626,402                 604,800
# 3       8/21/2023           13              626,402                 604,800
# 4       8/21/2023           13              626,402                 604,800
# ..            ...          ...                  ...                     ...
# 486      7/5/2023            0            5,864,405               1,209,600
# 487      7/5/2023            0            5,864,405               1,209,600
# 488      7/5/2023            0            5,864,405               1,209,600
# 489      7/5/2023            0            5,864,405               1,209,600
# 490      7/5/2023            0            5,864,405               1,209,600
#
#     parentKey parentId sprintStatus      storyKey  isSubTask storyType  \
# 0           -        -       active       EPP-111      False     Story
# 1           -        -       active       EPP-138      False      Task
# 2           -        -       active       EPP-107      False     Story
# 3           -        -       active       EPP-134      False     Story
# 4           -        -       active       EPP-133      False     Story
# ..        ...      ...          ...           ...        ...       ...
# 486         -        -       active  HIVERSE-9512      False       Bug
# 487         -        -       active  HIVERSE-9526      False       Bug
# 488         -        -       active  HIVERSE-9551      False       Bug
# 489         -        -       active  HIVERSE-9777      False       Bug
# 490         -        -       active  HIVERSE-9778      False       Bug
#
#     timeSpent storyStatus
# 0           0       To Do
# 1           0       To Do
# 2       7,200        Done
# 3           0        Done
# 4      50,400        Done
# ..        ...         ...
# 486         0        Done
# 487       600        Done
# 488         0        Done
# 489       600        Done
# 490         0        Done
#
# [491 rows x 16 columns]

# %%
df
# Out:
#     sprintId           sprintName              projectName sprintStartDate  \
# 0      1,426         EPP Sprint 9  Eurisko Platform Portal       8/14/2023
# 1      1,426         EPP Sprint 9  Eurisko Platform Portal       8/14/2023
# 2      1,426         EPP Sprint 9  Eurisko Platform Portal       8/14/2023
# 3      1,426         EPP Sprint 9  Eurisko Platform Portal       8/14/2023
# 4      1,426         EPP Sprint 9  Eurisko Platform Portal       8/14/2023
# ..       ...                  ...                      ...             ...
# 486    1,363  HIVERSE - Sprint 77                  Hiverse       6/21/2023
# 487    1,363  HIVERSE - Sprint 77                  Hiverse       6/21/2023
# 488    1,363  HIVERSE - Sprint 77                  Hiverse       6/21/2023
# 489    1,363  HIVERSE - Sprint 77                  Hiverse       6/21/2023
# 490    1,363  HIVERSE - Sprint 77                  Hiverse       6/21/2023
#
#     sprintEndDate  storyPoints sprintDurationPassed sprintDurationEstimated  \
# 0       8/21/2023           13              612,001                 604,800
# 1       8/21/2023            8              612,001                 604,800
# 2       8/21/2023           13              626,402                 604,800
# 3       8/21/2023           13              626,402                 604,800
# 4       8/21/2023           13              626,402                 604,800
# ..            ...          ...                  ...                     ...
# 486      7/5/2023            0            5,864,405               1,209,600
# 487      7/5/2023            0            5,864,405               1,209,600
# 488      7/5/2023            0            5,864,405               1,209,600
# 489      7/5/2023            0            5,864,405               1,209,600
# 490      7/5/2023            0            5,864,405               1,209,600
#
#     parentKey parentId sprintStatus      storyKey  isSubTask storyType  \
# 0           -        -       active       EPP-111      False     Story
# 1           -        -       active       EPP-138      False      Task
# 2           -        -       active       EPP-107      False     Story
# 3           -        -       active       EPP-134      False     Story
# 4           -        -       active       EPP-133      False     Story
# ..        ...      ...          ...           ...        ...       ...
# 486         -        -       active  HIVERSE-9512      False       Bug
# 487         -        -       active  HIVERSE-9526      False       Bug
# 488         -        -       active  HIVERSE-9551      False       Bug
# 489         -        -       active  HIVERSE-9777      False       Bug
# 490         -        -       active  HIVERSE-9778      False       Bug
#
#     timeSpent storyStatus
# 0           0       To Do
# 1           0       To Do
# 2       7,200        Done
# 3           0        Done
# 4      50,400        Done
# ..        ...         ...
# 486         0        Done
# 487       600        Done
# 488         0        Done
# 489       600        Done
# 490         0        Done
#
# [491 rows x 16 columns]

# %%
df1["sprintEndDate"] = pd.to_datetime(df1['sprintEndDate'])

# %%
df1
# Out:
#     sprintId           sprintName              projectName sprintStartDate  \
# 0      1,426         EPP Sprint 9  Eurisko Platform Portal      2023-08-14
# 1      1,426         EPP Sprint 9  Eurisko Platform Portal      2023-08-14
# 2      1,426         EPP Sprint 9  Eurisko Platform Portal      2023-08-14
# 3      1,426         EPP Sprint 9  Eurisko Platform Portal      2023-08-14
# 4      1,426         EPP Sprint 9  Eurisko Platform Portal      2023-08-14
# ..       ...                  ...                      ...             ...
# 486    1,363  HIVERSE - Sprint 77                  Hiverse      2023-06-21
# 487    1,363  HIVERSE - Sprint 77                  Hiverse      2023-06-21
# 488    1,363  HIVERSE - Sprint 77                  Hiverse      2023-06-21
# 489    1,363  HIVERSE - Sprint 77                  Hiverse      2023-06-21
# 490    1,363  HIVERSE - Sprint 77                  Hiverse      2023-06-21
#
#     sprintEndDate  storyPoints sprintDurationPassed sprintDurationEstimated  \
# 0      2023-08-21           13              612,001                 604,800
# 1      2023-08-21            8              612,001                 604,800
# 2      2023-08-21           13              626,402                 604,800
# 3      2023-08-21           13              626,402                 604,800
# 4      2023-08-21           13              626,402                 604,800
# ..            ...          ...                  ...                     ...
# 486    2023-07-05            0            5,864,405               1,209,600
# 487    2023-07-05            0            5,864,405               1,209,600
# 488    2023-07-05            0            5,864,405               1,209,600
# 489    2023-07-05            0            5,864,405               1,209,600
# 490    2023-07-05            0            5,864,405               1,209,600
#
#     parentKey parentId sprintStatus      storyKey  isSubTask storyType  \
# 0           -        -       active       EPP-111      False     Story
# 1           -        -       active       EPP-138      False      Task
# 2           -        -       active       EPP-107      False     Story
# 3           -        -       active       EPP-134      False     Story
# 4           -        -       active       EPP-133      False     Story
# ..        ...      ...          ...           ...        ...       ...
# 486         -        -       active  HIVERSE-9512      False       Bug
# 487         -        -       active  HIVERSE-9526      False       Bug
# 488         -        -       active  HIVERSE-9551      False       Bug
# 489         -        -       active  HIVERSE-9777      False       Bug
# 490         -        -       active  HIVERSE-9778      False       Bug
#
#     timeSpent storyStatus
# 0           0       To Do
# 1           0       To Do
# 2       7,200        Done
# 3           0        Done
# 4      50,400        Done
# ..        ...         ...
# 486         0        Done
# 487       600        Done
# 488         0        Done
# 489       600        Done
# 490         0        Done
#
# [491 rows x 16 columns]

# %%
df1["sprintDuration"] = df1["sprintEndDate"] - df1["sprintStartDate"]

# %%
df1
# Out:
#     sprintId           sprintName              projectName sprintStartDate  \
# 0      1,426         EPP Sprint 9  Eurisko Platform Portal      2023-08-14
# 1      1,426         EPP Sprint 9  Eurisko Platform Portal      2023-08-14
# 2      1,426         EPP Sprint 9  Eurisko Platform Portal      2023-08-14
# 3      1,426         EPP Sprint 9  Eurisko Platform Portal      2023-08-14
# 4      1,426         EPP Sprint 9  Eurisko Platform Portal      2023-08-14
# ..       ...                  ...                      ...             ...
# 486    1,363  HIVERSE - Sprint 77                  Hiverse      2023-06-21
# 487    1,363  HIVERSE - Sprint 77                  Hiverse      2023-06-21
# 488    1,363  HIVERSE - Sprint 77                  Hiverse      2023-06-21
# 489    1,363  HIVERSE - Sprint 77                  Hiverse      2023-06-21
# 490    1,363  HIVERSE - Sprint 77                  Hiverse      2023-06-21
#
#     sprintEndDate  storyPoints sprintDurationPassed sprintDurationEstimated  \
# 0      2023-08-21           13              612,001                 604,800
# 1      2023-08-21            8              612,001                 604,800
# 2      2023-08-21           13              626,402                 604,800
# 3      2023-08-21           13              626,402                 604,800
# 4      2023-08-21           13              626,402                 604,800
# ..            ...          ...                  ...                     ...
# 486    2023-07-05            0            5,864,405               1,209,600
# 487    2023-07-05            0            5,864,405               1,209,600
# 488    2023-07-05            0            5,864,405               1,209,600
# 489    2023-07-05            0            5,864,405               1,209,600
# 490    2023-07-05            0            5,864,405               1,209,600
#
#     parentKey parentId sprintStatus      storyKey  isSubTask storyType  \
# 0           -        -       active       EPP-111      False     Story
# 1           -        -       active       EPP-138      False      Task
# 2           -        -       active       EPP-107      False     Story
# 3           -        -       active       EPP-134      False     Story
# 4           -        -       active       EPP-133      False     Story
# ..        ...      ...          ...           ...        ...       ...
# 486         -        -       active  HIVERSE-9512      False       Bug
# 487         -        -       active  HIVERSE-9526      False       Bug
# 488         -        -       active  HIVERSE-9551      False       Bug
# 489         -        -       active  HIVERSE-9777      False       Bug
# 490         -        -       active  HIVERSE-9778      False       Bug
#
#     timeSpent storyStatus sprintDuration
# 0           0       To Do         7 days
# 1           0       To Do         7 days
# 2       7,200        Done         7 days
# 3           0        Done         7 days
# 4      50,400        Done         7 days
# ..        ...         ...            ...
# 486         0        Done        14 days
# 487       600        Done        14 days
# 488         0        Done        14 days
# 489       600        Done        14 days
# 490         0        Done        14 days
#
# [491 rows x 17 columns]

# %%
def group_status(status):
    if status.lower() == 'done':
        return 'done'
    else:
        return 'not done'

# %%
def group_status(status):
    if status.lower() == 'done':
        return 'done'
    else:
        return 'not done'
    
df1['storystatus(group)'] = df1["storyStatus"].apply(group_status)

# %%
df1
# Out:
#     sprintId           sprintName              projectName sprintStartDate  \
# 0      1,426         EPP Sprint 9  Eurisko Platform Portal      2023-08-14
# 1      1,426         EPP Sprint 9  Eurisko Platform Portal      2023-08-14
# 2      1,426         EPP Sprint 9  Eurisko Platform Portal      2023-08-14
# 3      1,426         EPP Sprint 9  Eurisko Platform Portal      2023-08-14
# 4      1,426         EPP Sprint 9  Eurisko Platform Portal      2023-08-14
# ..       ...                  ...                      ...             ...
# 486    1,363  HIVERSE - Sprint 77                  Hiverse      2023-06-21
# 487    1,363  HIVERSE - Sprint 77                  Hiverse      2023-06-21
# 488    1,363  HIVERSE - Sprint 77                  Hiverse      2023-06-21
# 489    1,363  HIVERSE - Sprint 77                  Hiverse      2023-06-21
# 490    1,363  HIVERSE - Sprint 77                  Hiverse      2023-06-21
#
#     sprintEndDate  storyPoints sprintDurationPassed sprintDurationEstimated  \
# 0      2023-08-21           13              612,001                 604,800
# 1      2023-08-21            8              612,001                 604,800
# 2      2023-08-21           13              626,402                 604,800
# 3      2023-08-21           13              626,402                 604,800
# 4      2023-08-21           13              626,402                 604,800
# ..            ...          ...                  ...                     ...
# 486    2023-07-05            0            5,864,405               1,209,600
# 487    2023-07-05            0            5,864,405               1,209,600
# 488    2023-07-05            0            5,864,405               1,209,600
# 489    2023-07-05            0            5,864,405               1,209,600
# 490    2023-07-05            0            5,864,405               1,209,600
#
#     parentKey parentId sprintStatus      storyKey  isSubTask storyType  \
# 0           -        -       active       EPP-111      False     Story
# 1           -        -       active       EPP-138      False      Task
# 2           -        -       active       EPP-107      False     Story
# 3           -        -       active       EPP-134      False     Story
# 4           -        -       active       EPP-133      False     Story
# ..        ...      ...          ...           ...        ...       ...
# 486         -        -       active  HIVERSE-9512      False       Bug
# 487         -        -       active  HIVERSE-9526      False       Bug
# 488         -        -       active  HIVERSE-9551      False       Bug
# 489         -        -       active  HIVERSE-9777      False       Bug
# 490         -        -       active  HIVERSE-9778      False       Bug
#
#     timeSpent storyStatus sprintDuration storystatus(group)
# 0           0       To Do         7 days           not done
# 1           0       To Do         7 days           not done
# 2       7,200        Done         7 days               done
# 3           0        Done         7 days               done
# 4      50,400        Done         7 days               done
# ..        ...         ...            ...                ...
# 486         0        Done        14 days               done
# 487       600        Done        14 days               done
# 488         0        Done        14 days               done
# 489       600        Done        14 days               done
# 490         0        Done        14 days               done
#
# [491 rows x 18 columns]

# %%
df1[df1['storyKey'] == "HIVERSE-9329"]
# Out:
#     sprintId           sprintName projectName sprintStartDate sprintEndDate  \
# 236    1,393  HIVERSE - Sprint 78     Hiverse      2023-07-18    2023-07-25
#
#      storyPoints sprintDurationPassed sprintDurationEstimated parentKey  \
# 236            0            3,604,202                 541,200         -
#
#     parentId sprintStatus      storyKey  isSubTask storyType timeSpent  \
# 236        -       active  HIVERSE-9329      False       Bug         0
#
#      storyStatus sprintDuration storystatus(group)
# 236  Q.A Testing         7 days           not done

# %%
df1.loc[12]
# Out:
# sprintId                                            1,418
# sprintName                 Sprint 77.1 - KPI Enhancements
# projectName                                       Hiverse
# sprintStartDate                       2023-08-10 00:00:00
# sprintEndDate                         2023-08-17 00:00:00
# storyPoints                                             0
# sprintDurationPassed                            1,565,330
# sprintDurationEstimated                           604,782
# parentKey                                               -
# parentId                                                -
# sprintStatus                                       active
# storyKey                                     HIVERSE-9660
# isSubTask                                           False
# storyType                                             Bug
# timeSpent                                          10,800
# storyStatus                                          Done
# sprintDuration                            7 days 00:00:00
# storystatus(group)                                   done
# Name: 12, dtype: object

# %%
df1.loc[236]
# Out:
# sprintId                                 1,393
# sprintName                 HIVERSE - Sprint 78
# projectName                            Hiverse
# sprintStartDate            2023-07-18 00:00:00
# sprintEndDate              2023-07-25 00:00:00
# storyPoints                                  0
# sprintDurationPassed                 3,604,202
# sprintDurationEstimated                541,200
# parentKey                                    -
# parentId                                     -
# sprintStatus                            active
# storyKey                          HIVERSE-9329
# isSubTask                                False
# storyType                                  Bug
# timeSpent                                    0
# storyStatus                        Q.A Testing
# sprintDuration                 7 days 00:00:00
# storystatus(group)                    not done
# Name: 236, dtype: object

# %%
df1
# Out:
#     sprintId           sprintName              projectName sprintStartDate  \
# 0      1,426         EPP Sprint 9  Eurisko Platform Portal      2023-08-14
# 1      1,426         EPP Sprint 9  Eurisko Platform Portal      2023-08-14
# 2      1,426         EPP Sprint 9  Eurisko Platform Portal      2023-08-14
# 3      1,426         EPP Sprint 9  Eurisko Platform Portal      2023-08-14
# 4      1,426         EPP Sprint 9  Eurisko Platform Portal      2023-08-14
# ..       ...                  ...                      ...             ...
# 486    1,363  HIVERSE - Sprint 77                  Hiverse      2023-06-21
# 487    1,363  HIVERSE - Sprint 77                  Hiverse      2023-06-21
# 488    1,363  HIVERSE - Sprint 77                  Hiverse      2023-06-21
# 489    1,363  HIVERSE - Sprint 77                  Hiverse      2023-06-21
# 490    1,363  HIVERSE - Sprint 77                  Hiverse      2023-06-21
#
#     sprintEndDate  storyPoints sprintDurationPassed sprintDurationEstimated  \
# 0      2023-08-21           13              612,001                 604,800
# 1      2023-08-21            8              612,001                 604,800
# 2      2023-08-21           13              626,402                 604,800
# 3      2023-08-21           13              626,402                 604,800
# 4      2023-08-21           13              626,402                 604,800
# ..            ...          ...                  ...                     ...
# 486    2023-07-05            0            5,864,405               1,209,600
# 487    2023-07-05            0            5,864,405               1,209,600
# 488    2023-07-05            0            5,864,405               1,209,600
# 489    2023-07-05            0            5,864,405               1,209,600
# 490    2023-07-05            0            5,864,405               1,209,600
#
#     parentKey parentId sprintStatus      storyKey  isSubTask storyType  \
# 0           -        -       active       EPP-111      False     Story
# 1           -        -       active       EPP-138      False      Task
# 2           -        -       active       EPP-107      False     Story
# 3           -        -       active       EPP-134      False     Story
# 4           -        -       active       EPP-133      False     Story
# ..        ...      ...          ...           ...        ...       ...
# 486         -        -       active  HIVERSE-9512      False       Bug
# 487         -        -       active  HIVERSE-9526      False       Bug
# 488         -        -       active  HIVERSE-9551      False       Bug
# 489         -        -       active  HIVERSE-9777      False       Bug
# 490         -        -       active  HIVERSE-9778      False       Bug
#
#     timeSpent storyStatus sprintDuration storystatus(group)
# 0           0       To Do         7 days           not done
# 1           0       To Do         7 days           not done
# 2       7,200        Done         7 days               done
# 3           0        Done         7 days               done
# 4      50,400        Done         7 days               done
# ..        ...         ...            ...                ...
# 486         0        Done        14 days               done
# 487       600        Done        14 days               done
# 488         0        Done        14 days               done
# 489       600        Done        14 days               done
# 490         0        Done        14 days               done
#
# [491 rows x 18 columns]

# %%
type(df1["sprintDurationPassed"][1])
# Out:
# str

# %%
df
# Out:
#     sprintId           sprintName              projectName sprintStartDate  \
# 0      1,426         EPP Sprint 9  Eurisko Platform Portal       8/14/2023
# 1      1,426         EPP Sprint 9  Eurisko Platform Portal       8/14/2023
# 2      1,426         EPP Sprint 9  Eurisko Platform Portal       8/14/2023
# 3      1,426         EPP Sprint 9  Eurisko Platform Portal       8/14/2023
# 4      1,426         EPP Sprint 9  Eurisko Platform Portal       8/14/2023
# ..       ...                  ...                      ...             ...
# 486    1,363  HIVERSE - Sprint 77                  Hiverse       6/21/2023
# 487    1,363  HIVERSE - Sprint 77                  Hiverse       6/21/2023
# 488    1,363  HIVERSE - Sprint 77                  Hiverse       6/21/2023
# 489    1,363  HIVERSE - Sprint 77                  Hiverse       6/21/2023
# 490    1,363  HIVERSE - Sprint 77                  Hiverse       6/21/2023
#
#     sprintEndDate  storyPoints sprintDurationPassed sprintDurationEstimated  \
# 0       8/21/2023           13              612,001                 604,800
# 1       8/21/2023            8              612,001                 604,800
# 2       8/21/2023           13              626,402                 604,800
# 3       8/21/2023           13              626,402                 604,800
# 4       8/21/2023           13              626,402                 604,800
# ..            ...          ...                  ...                     ...
# 486      7/5/2023            0            5,864,405               1,209,600
# 487      7/5/2023            0            5,864,405               1,209,600
# 488      7/5/2023            0            5,864,405               1,209,600
# 489      7/5/2023            0            5,864,405               1,209,600
# 490      7/5/2023            0            5,864,405               1,209,600
#
#     parentKey parentId sprintStatus      storyKey  isSubTask storyType  \
# 0           -        -       active       EPP-111      False     Story
# 1           -        -       active       EPP-138      False      Task
# 2           -        -       active       EPP-107      False     Story
# 3           -        -       active       EPP-134      False     Story
# 4           -        -       active       EPP-133      False     Story
# ..        ...      ...          ...           ...        ...       ...
# 486         -        -       active  HIVERSE-9512      False       Bug
# 487         -        -       active  HIVERSE-9526      False       Bug
# 488         -        -       active  HIVERSE-9551      False       Bug
# 489         -        -       active  HIVERSE-9777      False       Bug
# 490         -        -       active  HIVERSE-9778      False       Bug
#
#     timeSpent storyStatus
# 0           0       To Do
# 1           0       To Do
# 2       7,200        Done
# 3           0        Done
# 4      50,400        Done
# ..        ...         ...
# 486         0        Done
# 487       600        Done
# 488         0        Done
# 489       600        Done
# 490         0        Done
#
# [491 rows x 16 columns]

# %%
df1 = df.copy()

# %%
df1
# Out:
#     sprintId           sprintName              projectName sprintStartDate  \
# 0      1,426         EPP Sprint 9  Eurisko Platform Portal       8/14/2023
# 1      1,426         EPP Sprint 9  Eurisko Platform Portal       8/14/2023
# 2      1,426         EPP Sprint 9  Eurisko Platform Portal       8/14/2023
# 3      1,426         EPP Sprint 9  Eurisko Platform Portal       8/14/2023
# 4      1,426         EPP Sprint 9  Eurisko Platform Portal       8/14/2023
# ..       ...                  ...                      ...             ...
# 486    1,363  HIVERSE - Sprint 77                  Hiverse       6/21/2023
# 487    1,363  HIVERSE - Sprint 77                  Hiverse       6/21/2023
# 488    1,363  HIVERSE - Sprint 77                  Hiverse       6/21/2023
# 489    1,363  HIVERSE - Sprint 77                  Hiverse       6/21/2023
# 490    1,363  HIVERSE - Sprint 77                  Hiverse       6/21/2023
#
#     sprintEndDate  storyPoints sprintDurationPassed sprintDurationEstimated  \
# 0       8/21/2023           13              612,001                 604,800
# 1       8/21/2023            8              612,001                 604,800
# 2       8/21/2023           13              626,402                 604,800
# 3       8/21/2023           13              626,402                 604,800
# 4       8/21/2023           13              626,402                 604,800
# ..            ...          ...                  ...                     ...
# 486      7/5/2023            0            5,864,405               1,209,600
# 487      7/5/2023            0            5,864,405               1,209,600
# 488      7/5/2023            0            5,864,405               1,209,600
# 489      7/5/2023            0            5,864,405               1,209,600
# 490      7/5/2023            0            5,864,405               1,209,600
#
#     parentKey parentId sprintStatus      storyKey  isSubTask storyType  \
# 0           -        -       active       EPP-111      False     Story
# 1           -        -       active       EPP-138      False      Task
# 2           -        -       active       EPP-107      False     Story
# 3           -        -       active       EPP-134      False     Story
# 4           -        -       active       EPP-133      False     Story
# ..        ...      ...          ...           ...        ...       ...
# 486         -        -       active  HIVERSE-9512      False       Bug
# 487         -        -       active  HIVERSE-9526      False       Bug
# 488         -        -       active  HIVERSE-9551      False       Bug
# 489         -        -       active  HIVERSE-9777      False       Bug
# 490         -        -       active  HIVERSE-9778      False       Bug
#
#     timeSpent storyStatus
# 0           0       To Do
# 1           0       To Do
# 2       7,200        Done
# 3           0        Done
# 4      50,400        Done
# ..        ...         ...
# 486         0        Done
# 487       600        Done
# 488         0        Done
# 489       600        Done
# 490         0        Done
#
# [491 rows x 16 columns]

# %%
def group_status(status):
    if status.lower() == 'done':
        return 'done'
    else:
        return 'not done'
    
df1['storystatus(group)'] = df1["storyStatus"].apply(group_status)

# %%
df1
# Out:
#     sprintId           sprintName              projectName sprintStartDate  \
# 0      1,426         EPP Sprint 9  Eurisko Platform Portal       8/14/2023
# 1      1,426         EPP Sprint 9  Eurisko Platform Portal       8/14/2023
# 2      1,426         EPP Sprint 9  Eurisko Platform Portal       8/14/2023
# 3      1,426         EPP Sprint 9  Eurisko Platform Portal       8/14/2023
# 4      1,426         EPP Sprint 9  Eurisko Platform Portal       8/14/2023
# ..       ...                  ...                      ...             ...
# 486    1,363  HIVERSE - Sprint 77                  Hiverse       6/21/2023
# 487    1,363  HIVERSE - Sprint 77                  Hiverse       6/21/2023
# 488    1,363  HIVERSE - Sprint 77                  Hiverse       6/21/2023
# 489    1,363  HIVERSE - Sprint 77                  Hiverse       6/21/2023
# 490    1,363  HIVERSE - Sprint 77                  Hiverse       6/21/2023
#
#     sprintEndDate  storyPoints sprintDurationPassed sprintDurationEstimated  \
# 0       8/21/2023           13              612,001                 604,800
# 1       8/21/2023            8              612,001                 604,800
# 2       8/21/2023           13              626,402                 604,800
# 3       8/21/2023           13              626,402                 604,800
# 4       8/21/2023           13              626,402                 604,800
# ..            ...          ...                  ...                     ...
# 486      7/5/2023            0            5,864,405               1,209,600
# 487      7/5/2023            0            5,864,405               1,209,600
# 488      7/5/2023            0            5,864,405               1,209,600
# 489      7/5/2023            0            5,864,405               1,209,600
# 490      7/5/2023            0            5,864,405               1,209,600
#
#     parentKey parentId sprintStatus      storyKey  isSubTask storyType  \
# 0           -        -       active       EPP-111      False     Story
# 1           -        -       active       EPP-138      False      Task
# 2           -        -       active       EPP-107      False     Story
# 3           -        -       active       EPP-134      False     Story
# 4           -        -       active       EPP-133      False     Story
# ..        ...      ...          ...           ...        ...       ...
# 486         -        -       active  HIVERSE-9512      False       Bug
# 487         -        -       active  HIVERSE-9526      False       Bug
# 488         -        -       active  HIVERSE-9551      False       Bug
# 489         -        -       active  HIVERSE-9777      False       Bug
# 490         -        -       active  HIVERSE-9778      False       Bug
#
#     timeSpent storyStatus storystatus(group)
# 0           0       To Do           not done
# 1           0       To Do           not done
# 2       7,200        Done               done
# 3           0        Done               done
# 4      50,400        Done               done
# ..        ...         ...                ...
# 486         0        Done               done
# 487       600        Done               done
# 488         0        Done               done
# 489       600        Done               done
# 490         0        Done               done
#
# [491 rows x 17 columns]

# %%
df1['sprintDurationEstimated'] = df1['sprintDurationEstimated'].str.replace(',', '')

# %%
df1['sprintDurationPassed'] = df1['sprintDurationPassed'].str.replace(',', '')

# %%
df['sprintDurationEstimated'].replace('', '0', inplace=True)

# %%
df1['sprintDurationEstimated'].replace('', '0', inplace=True)

# %%
df1['sprintDurationPassed'].replace('', '0', inplace=True)

# %%
df1
# Out:
#     sprintId           sprintName              projectName sprintStartDate  \
# 0      1,426         EPP Sprint 9  Eurisko Platform Portal       8/14/2023
# 1      1,426         EPP Sprint 9  Eurisko Platform Portal       8/14/2023
# 2      1,426         EPP Sprint 9  Eurisko Platform Portal       8/14/2023
# 3      1,426         EPP Sprint 9  Eurisko Platform Portal       8/14/2023
# 4      1,426         EPP Sprint 9  Eurisko Platform Portal       8/14/2023
# ..       ...                  ...                      ...             ...
# 486    1,363  HIVERSE - Sprint 77                  Hiverse       6/21/2023
# 487    1,363  HIVERSE - Sprint 77                  Hiverse       6/21/2023
# 488    1,363  HIVERSE - Sprint 77                  Hiverse       6/21/2023
# 489    1,363  HIVERSE - Sprint 77                  Hiverse       6/21/2023
# 490    1,363  HIVERSE - Sprint 77                  Hiverse       6/21/2023
#
#     sprintEndDate  storyPoints sprintDurationPassed sprintDurationEstimated  \
# 0       8/21/2023           13               612001                  604800
# 1       8/21/2023            8               612001                  604800
# 2       8/21/2023           13               626402                  604800
# 3       8/21/2023           13               626402                  604800
# 4       8/21/2023           13               626402                  604800
# ..            ...          ...                  ...                     ...
# 486      7/5/2023            0              5864405                 1209600
# 487      7/5/2023            0              5864405                 1209600
# 488      7/5/2023            0              5864405                 1209600
# 489      7/5/2023            0              5864405                 1209600
# 490      7/5/2023            0              5864405                 1209600
#
#     parentKey parentId sprintStatus      storyKey  isSubTask storyType  \
# 0           -        -       active       EPP-111      False     Story
# 1           -        -       active       EPP-138      False      Task
# 2           -        -       active       EPP-107      False     Story
# 3           -        -       active       EPP-134      False     Story
# 4           -        -       active       EPP-133      False     Story
# ..        ...      ...          ...           ...        ...       ...
# 486         -        -       active  HIVERSE-9512      False       Bug
# 487         -        -       active  HIVERSE-9526      False       Bug
# 488         -        -       active  HIVERSE-9551      False       Bug
# 489         -        -       active  HIVERSE-9777      False       Bug
# 490         -        -       active  HIVERSE-9778      False       Bug
#
#     timeSpent storyStatus storystatus(group)
# 0           0       To Do           not done
# 1           0       To Do           not done
# 2       7,200        Done               done
# 3           0        Done               done
# 4      50,400        Done               done
# ..        ...         ...                ...
# 486         0        Done               done
# 487       600        Done               done
# 488         0        Done               done
# 489       600        Done               done
# 490         0        Done               done
#
# [491 rows x 17 columns]

# %%
df1['sprintDurationPassed'].replace('-', '0', inplace=True)

# %%
df1['sprintDurationEstimated'].replace('-', '0', inplace=True)

# %%
df1['sprintDurationEstimated'] = df1['sprintDurationEstimated'].astype(int)

# %%
df1['sprintDurationPassed'] = df1['sprintDurationPassed'].astype(int)

# %%
df1
# Out:
#     sprintId           sprintName              projectName sprintStartDate  \
# 0      1,426         EPP Sprint 9  Eurisko Platform Portal       8/14/2023
# 1      1,426         EPP Sprint 9  Eurisko Platform Portal       8/14/2023
# 2      1,426         EPP Sprint 9  Eurisko Platform Portal       8/14/2023
# 3      1,426         EPP Sprint 9  Eurisko Platform Portal       8/14/2023
# 4      1,426         EPP Sprint 9  Eurisko Platform Portal       8/14/2023
# ..       ...                  ...                      ...             ...
# 486    1,363  HIVERSE - Sprint 77                  Hiverse       6/21/2023
# 487    1,363  HIVERSE - Sprint 77                  Hiverse       6/21/2023
# 488    1,363  HIVERSE - Sprint 77                  Hiverse       6/21/2023
# 489    1,363  HIVERSE - Sprint 77                  Hiverse       6/21/2023
# 490    1,363  HIVERSE - Sprint 77                  Hiverse       6/21/2023
#
#     sprintEndDate  storyPoints  sprintDurationPassed  sprintDurationEstimated  \
# 0       8/21/2023           13                612001                   604800
# 1       8/21/2023            8                612001                   604800
# 2       8/21/2023           13                626402                   604800
# 3       8/21/2023           13                626402                   604800
# 4       8/21/2023           13                626402                   604800
# ..            ...          ...                   ...                      ...
# 486      7/5/2023            0               5864405                  1209600
# 487      7/5/2023            0               5864405                  1209600
# 488      7/5/2023            0               5864405                  1209600
# 489      7/5/2023            0               5864405                  1209600
# 490      7/5/2023            0               5864405                  1209600
#
#     parentKey parentId sprintStatus      storyKey  isSubTask storyType  \
# 0           -        -       active       EPP-111      False     Story
# 1           -        -       active       EPP-138      False      Task
# 2           -        -       active       EPP-107      False     Story
# 3           -        -       active       EPP-134      False     Story
# 4           -        -       active       EPP-133      False     Story
# ..        ...      ...          ...           ...        ...       ...
# 486         -        -       active  HIVERSE-9512      False       Bug
# 487         -        -       active  HIVERSE-9526      False       Bug
# 488         -        -       active  HIVERSE-9551      False       Bug
# 489         -        -       active  HIVERSE-9777      False       Bug
# 490         -        -       active  HIVERSE-9778      False       Bug
#
#     timeSpent storyStatus storystatus(group)
# 0           0       To Do           not done
# 1           0       To Do           not done
# 2       7,200        Done               done
# 3           0        Done               done
# 4      50,400        Done               done
# ..        ...         ...                ...
# 486         0        Done               done
# 487       600        Done               done
# 488         0        Done               done
# 489       600        Done               done
# 490         0        Done               done
#
# [491 rows x 17 columns]

# %%
type(df1["sprintDurationPassed"][1])
# Out:
# numpy.int32

# %%
df1["sprintDurationEstimated(in hours)"] = df1["sprintDurationEstimated"] / 3600

# %%
df1["sprintDurationPasses(in hours)"] = df1["sprintDurationPassed"] / 3600

# %%
df1 = df1.rename(columns={'sprintDurationPasses(in hours)': 'sprintDurationPassed(in hours)'})
df1
# Out:
#     sprintId           sprintName              projectName sprintStartDate  \
# 0      1,426         EPP Sprint 9  Eurisko Platform Portal       8/14/2023
# 1      1,426         EPP Sprint 9  Eurisko Platform Portal       8/14/2023
# 2      1,426         EPP Sprint 9  Eurisko Platform Portal       8/14/2023
# 3      1,426         EPP Sprint 9  Eurisko Platform Portal       8/14/2023
# 4      1,426         EPP Sprint 9  Eurisko Platform Portal       8/14/2023
# ..       ...                  ...                      ...             ...
# 486    1,363  HIVERSE - Sprint 77                  Hiverse       6/21/2023
# 487    1,363  HIVERSE - Sprint 77                  Hiverse       6/21/2023
# 488    1,363  HIVERSE - Sprint 77                  Hiverse       6/21/2023
# 489    1,363  HIVERSE - Sprint 77                  Hiverse       6/21/2023
# 490    1,363  HIVERSE - Sprint 77                  Hiverse       6/21/2023
#
#     sprintEndDate  storyPoints  sprintDurationPassed  sprintDurationEstimated  \
# 0       8/21/2023           13                612001                   604800
# 1       8/21/2023            8                612001                   604800
# 2       8/21/2023           13                626402                   604800
# 3       8/21/2023           13                626402                   604800
# 4       8/21/2023           13                626402                   604800
# ..            ...          ...                   ...                      ...
# 486      7/5/2023            0               5864405                  1209600
# 487      7/5/2023            0               5864405                  1209600
# 488      7/5/2023            0               5864405                  1209600
# 489      7/5/2023            0               5864405                  1209600
# 490      7/5/2023            0               5864405                  1209600
#
#     parentKey parentId sprintStatus      storyKey  isSubTask storyType  \
# 0           -        -       active       EPP-111      False     Story
# 1           -        -       active       EPP-138      False      Task
# 2           -        -       active       EPP-107      False     Story
# 3           -        -       active       EPP-134      False     Story
# 4           -        -       active       EPP-133      False     Story
# ..        ...      ...          ...           ...        ...       ...
# 486         -        -       active  HIVERSE-9512      False       Bug
# 487         -        -       active  HIVERSE-9526      False       Bug
# 488         -        -       active  HIVERSE-9551      False       Bug
# 489         -        -       active  HIVERSE-9777      False       Bug
# 490         -        -       active  HIVERSE-9778      False       Bug
#
#     timeSpent storyStatus storystatus(group)  \
# 0           0       To Do           not done
# 1           0       To Do           not done
# 2       7,200        Done               done
# 3           0        Done               done
# 4      50,400        Done               done
# ..        ...         ...                ...
# 486         0        Done               done
# 487       600        Done               done
# 488         0        Done               done
# 489       600        Done               done
# 490         0        Done               done
#
#      sprintDurationEstimated(in hours)  sprintDurationPassed(in hours)
# 0                                168.0                      170.000278
# 1                                168.0                      170.000278
# 2                                168.0                      174.000556
# 3                                168.0                      174.000556
# 4                                168.0                      174.000556
# ..                                 ...                             ...
# 486                              336.0                     1629.001389
# 487                              336.0                     1629.001389
# 488                              336.0                     1629.001389
# 489                              336.0                     1629.001389
# 490                              336.0                     1629.001389
#
# [491 rows x 19 columns]

# %%
df1 = df1.rename(columns={'storystatus(group)': 'storystatus(list)'})

# %%
df1
# Out:
#     sprintId           sprintName              projectName sprintStartDate  \
# 0      1,426         EPP Sprint 9  Eurisko Platform Portal       8/14/2023
# 1      1,426         EPP Sprint 9  Eurisko Platform Portal       8/14/2023
# 2      1,426         EPP Sprint 9  Eurisko Platform Portal       8/14/2023
# 3      1,426         EPP Sprint 9  Eurisko Platform Portal       8/14/2023
# 4      1,426         EPP Sprint 9  Eurisko Platform Portal       8/14/2023
# ..       ...                  ...                      ...             ...
# 486    1,363  HIVERSE - Sprint 77                  Hiverse       6/21/2023
# 487    1,363  HIVERSE - Sprint 77                  Hiverse       6/21/2023
# 488    1,363  HIVERSE - Sprint 77                  Hiverse       6/21/2023
# 489    1,363  HIVERSE - Sprint 77                  Hiverse       6/21/2023
# 490    1,363  HIVERSE - Sprint 77                  Hiverse       6/21/2023
#
#     sprintEndDate  storyPoints  sprintDurationPassed  sprintDurationEstimated  \
# 0       8/21/2023           13                612001                   604800
# 1       8/21/2023            8                612001                   604800
# 2       8/21/2023           13                626402                   604800
# 3       8/21/2023           13                626402                   604800
# 4       8/21/2023           13                626402                   604800
# ..            ...          ...                   ...                      ...
# 486      7/5/2023            0               5864405                  1209600
# 487      7/5/2023            0               5864405                  1209600
# 488      7/5/2023            0               5864405                  1209600
# 489      7/5/2023            0               5864405                  1209600
# 490      7/5/2023            0               5864405                  1209600
#
#     parentKey parentId sprintStatus      storyKey  isSubTask storyType  \
# 0           -        -       active       EPP-111      False     Story
# 1           -        -       active       EPP-138      False      Task
# 2           -        -       active       EPP-107      False     Story
# 3           -        -       active       EPP-134      False     Story
# 4           -        -       active       EPP-133      False     Story
# ..        ...      ...          ...           ...        ...       ...
# 486         -        -       active  HIVERSE-9512      False       Bug
# 487         -        -       active  HIVERSE-9526      False       Bug
# 488         -        -       active  HIVERSE-9551      False       Bug
# 489         -        -       active  HIVERSE-9777      False       Bug
# 490         -        -       active  HIVERSE-9778      False       Bug
#
#     timeSpent storyStatus storystatus(list)  \
# 0           0       To Do          not done
# 1           0       To Do          not done
# 2       7,200        Done              done
# 3           0        Done              done
# 4      50,400        Done              done
# ..        ...         ...               ...
# 486         0        Done              done
# 487       600        Done              done
# 488         0        Done              done
# 489       600        Done              done
# 490         0        Done              done
#
#      sprintDurationEstimated(in hours)  sprintDurationPassed(in hours)
# 0                                168.0                      170.000278
# 1                                168.0                      170.000278
# 2                                168.0                      174.000556
# 3                                168.0                      174.000556
# 4                                168.0                      174.000556
# ..                                 ...                             ...
# 486                              336.0                     1629.001389
# 487                              336.0                     1629.001389
# 488                              336.0                     1629.001389
# 489                              336.0                     1629.001389
# 490                              336.0                     1629.001389
#
# [491 rows x 19 columns]

# %%
df1 = df1.rename(columns={'sprintDurationPasses(in hours)': 'sprintDurationPassed(in hours)'})

# %%
df1["sprintDurationDifference(in hours)"] = df1["sprintDurationPassed(in hours)"] - df1["sprintDurationEstimated(in hours)"]

# %%
(df1["storyType"] == "sub Task")
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 486    False
# 487    False
# 488    False
# 489    False
# 490    False
# Name: storyType, Length: 491, dtype: bool

# %%
def group_parent_id(row):
    if row['isSubTask']:
        return 'contains Parent'
    else:
        return 'No Parent'
    
df1['parentId(List)'] = df1.apply(group_parent_id, axis=1)

# %%
df1
# Out:
#     sprintId           sprintName              projectName sprintStartDate  \
# 0      1,426         EPP Sprint 9  Eurisko Platform Portal       8/14/2023
# 1      1,426         EPP Sprint 9  Eurisko Platform Portal       8/14/2023
# 2      1,426         EPP Sprint 9  Eurisko Platform Portal       8/14/2023
# 3      1,426         EPP Sprint 9  Eurisko Platform Portal       8/14/2023
# 4      1,426         EPP Sprint 9  Eurisko Platform Portal       8/14/2023
# ..       ...                  ...                      ...             ...
# 486    1,363  HIVERSE - Sprint 77                  Hiverse       6/21/2023
# 487    1,363  HIVERSE - Sprint 77                  Hiverse       6/21/2023
# 488    1,363  HIVERSE - Sprint 77                  Hiverse       6/21/2023
# 489    1,363  HIVERSE - Sprint 77                  Hiverse       6/21/2023
# 490    1,363  HIVERSE - Sprint 77                  Hiverse       6/21/2023
#
#     sprintEndDate  storyPoints  sprintDurationPassed  sprintDurationEstimated  \
# 0       8/21/2023           13                612001                   604800
# 1       8/21/2023            8                612001                   604800
# 2       8/21/2023           13                626402                   604800
# 3       8/21/2023           13                626402                   604800
# 4       8/21/2023           13                626402                   604800
# ..            ...          ...                   ...                      ...
# 486      7/5/2023            0               5864405                  1209600
# 487      7/5/2023            0               5864405                  1209600
# 488      7/5/2023            0               5864405                  1209600
# 489      7/5/2023            0               5864405                  1209600
# 490      7/5/2023            0               5864405                  1209600
#
#     parentKey parentId  ...      storyKey isSubTask  storyType timeSpent  \
# 0           -        -  ...       EPP-111     False      Story         0
# 1           -        -  ...       EPP-138     False       Task         0
# 2           -        -  ...       EPP-107     False      Story     7,200
# 3           -        -  ...       EPP-134     False      Story         0
# 4           -        -  ...       EPP-133     False      Story    50,400
# ..        ...      ...  ...           ...       ...        ...       ...
# 486         -        -  ...  HIVERSE-9512     False        Bug         0
# 487         -        -  ...  HIVERSE-9526     False        Bug       600
# 488         -        -  ...  HIVERSE-9551     False        Bug         0
# 489         -        -  ...  HIVERSE-9777     False        Bug       600
# 490         -        -  ...  HIVERSE-9778     False        Bug         0
#
#     storyStatus storystatus(list) sprintDurationEstimated(in hours)  \
# 0         To Do          not done                             168.0
# 1         To Do          not done                             168.0
# 2          Done              done                             168.0
# 3          Done              done                             168.0
# 4          Done              done                             168.0
# ..          ...               ...                               ...
# 486        Done              done                             336.0
# 487        Done              done                             336.0
# 488        Done              done                             336.0
# 489        Done              done                             336.0
# 490        Done              done                             336.0
#
#      sprintDurationPassed(in hours)  sprintDurationDifference(in hours)  \
# 0                        170.000278                            2.000278
# 1                        170.000278                            2.000278
# 2                        174.000556                            6.000556
# 3                        174.000556                            6.000556
# 4                        174.000556                            6.000556
# ..                              ...                                 ...
# 486                     1629.001389                         1293.001389
# 487                     1629.001389                         1293.001389
# 488                     1629.001389                         1293.001389
# 489                     1629.001389                         1293.001389
# 490                     1629.001389                         1293.001389
#
#      parentId(List)
# 0         No Parent
# 1         No Parent
# 2         No Parent
# 3         No Parent
# 4         No Parent
# ..              ...
# 486       No Parent
# 487       No Parent
# 488       No Parent
# 489       No Parent
# 490       No Parent
#
# [491 rows x 21 columns]

# %%
df
# Out:
#     sprintId           sprintName              projectName sprintStartDate  \
# 0      1,426         EPP Sprint 9  Eurisko Platform Portal       8/14/2023
# 1      1,426         EPP Sprint 9  Eurisko Platform Portal       8/14/2023
# 2      1,426         EPP Sprint 9  Eurisko Platform Portal       8/14/2023
# 3      1,426         EPP Sprint 9  Eurisko Platform Portal       8/14/2023
# 4      1,426         EPP Sprint 9  Eurisko Platform Portal       8/14/2023
# ..       ...                  ...                      ...             ...
# 486    1,363  HIVERSE - Sprint 77                  Hiverse       6/21/2023
# 487    1,363  HIVERSE - Sprint 77                  Hiverse       6/21/2023
# 488    1,363  HIVERSE - Sprint 77                  Hiverse       6/21/2023
# 489    1,363  HIVERSE - Sprint 77                  Hiverse       6/21/2023
# 490    1,363  HIVERSE - Sprint 77                  Hiverse       6/21/2023
#
#     sprintEndDate  storyPoints sprintDurationPassed sprintDurationEstimated  \
# 0       8/21/2023           13              612,001                 604,800
# 1       8/21/2023            8              612,001                 604,800
# 2       8/21/2023           13              626,402                 604,800
# 3       8/21/2023           13              626,402                 604,800
# 4       8/21/2023           13              626,402                 604,800
# ..            ...          ...                  ...                     ...
# 486      7/5/2023            0            5,864,405               1,209,600
# 487      7/5/2023            0            5,864,405               1,209,600
# 488      7/5/2023            0            5,864,405               1,209,600
# 489      7/5/2023            0            5,864,405               1,209,600
# 490      7/5/2023            0            5,864,405               1,209,600
#
#     parentKey parentId sprintStatus      storyKey  isSubTask storyType  \
# 0           -        -       active       EPP-111      False     Story
# 1           -        -       active       EPP-138      False      Task
# 2           -        -       active       EPP-107      False     Story
# 3           -        -       active       EPP-134      False     Story
# 4           -        -       active       EPP-133      False     Story
# ..        ...      ...          ...           ...        ...       ...
# 486         -        -       active  HIVERSE-9512      False       Bug
# 487         -        -       active  HIVERSE-9526      False       Bug
# 488         -        -       active  HIVERSE-9551      False       Bug
# 489         -        -       active  HIVERSE-9777      False       Bug
# 490         -        -       active  HIVERSE-9778      False       Bug
#
#     timeSpent storyStatus
# 0           0       To Do
# 1           0       To Do
# 2       7,200        Done
# 3           0        Done
# 4      50,400        Done
# ..        ...         ...
# 486         0        Done
# 487       600        Done
# 488         0        Done
# 489       600        Done
# 490         0        Done
#
# [491 rows x 16 columns]

# %%
df1
# Out:
#     sprintId           sprintName              projectName sprintStartDate  \
# 0      1,426         EPP Sprint 9  Eurisko Platform Portal       8/14/2023
# 1      1,426         EPP Sprint 9  Eurisko Platform Portal       8/14/2023
# 2      1,426         EPP Sprint 9  Eurisko Platform Portal       8/14/2023
# 3      1,426         EPP Sprint 9  Eurisko Platform Portal       8/14/2023
# 4      1,426         EPP Sprint 9  Eurisko Platform Portal       8/14/2023
# ..       ...                  ...                      ...             ...
# 486    1,363  HIVERSE - Sprint 77                  Hiverse       6/21/2023
# 487    1,363  HIVERSE - Sprint 77                  Hiverse       6/21/2023
# 488    1,363  HIVERSE - Sprint 77                  Hiverse       6/21/2023
# 489    1,363  HIVERSE - Sprint 77                  Hiverse       6/21/2023
# 490    1,363  HIVERSE - Sprint 77                  Hiverse       6/21/2023
#
#     sprintEndDate  storyPoints  sprintDurationPassed  sprintDurationEstimated  \
# 0       8/21/2023           13                612001                   604800
# 1       8/21/2023            8                612001                   604800
# 2       8/21/2023           13                626402                   604800
# 3       8/21/2023           13                626402                   604800
# 4       8/21/2023           13                626402                   604800
# ..            ...          ...                   ...                      ...
# 486      7/5/2023            0               5864405                  1209600
# 487      7/5/2023            0               5864405                  1209600
# 488      7/5/2023            0               5864405                  1209600
# 489      7/5/2023            0               5864405                  1209600
# 490      7/5/2023            0               5864405                  1209600
#
#     parentKey parentId  ...      storyKey isSubTask  storyType timeSpent  \
# 0           -        -  ...       EPP-111     False      Story         0
# 1           -        -  ...       EPP-138     False       Task         0
# 2           -        -  ...       EPP-107     False      Story     7,200
# 3           -        -  ...       EPP-134     False      Story         0
# 4           -        -  ...       EPP-133     False      Story    50,400
# ..        ...      ...  ...           ...       ...        ...       ...
# 486         -        -  ...  HIVERSE-9512     False        Bug         0
# 487         -        -  ...  HIVERSE-9526     False        Bug       600
# 488         -        -  ...  HIVERSE-9551     False        Bug         0
# 489         -        -  ...  HIVERSE-9777     False        Bug       600
# 490         -        -  ...  HIVERSE-9778     False        Bug         0
#
#     storyStatus storystatus(list) sprintDurationEstimated(in hours)  \
# 0         To Do          not done                             168.0
# 1         To Do          not done                             168.0
# 2          Done              done                             168.0
# 3          Done              done                             168.0
# 4          Done              done                             168.0
# ..          ...               ...                               ...
# 486        Done              done                             336.0
# 487        Done              done                             336.0
# 488        Done              done                             336.0
# 489        Done              done                             336.0
# 490        Done              done                             336.0
#
#      sprintDurationPassed(in hours)  sprintDurationDifference(in hours)  \
# 0                        170.000278                            2.000278
# 1                        170.000278                            2.000278
# 2                        174.000556                            6.000556
# 3                        174.000556                            6.000556
# 4                        174.000556                            6.000556
# ..                              ...                                 ...
# 486                     1629.001389                         1293.001389
# 487                     1629.001389                         1293.001389
# 488                     1629.001389                         1293.001389
# 489                     1629.001389                         1293.001389
# 490                     1629.001389                         1293.001389
#
#      parentId(List)
# 0         No Parent
# 1         No Parent
# 2         No Parent
# 3         No Parent
# 4         No Parent
# ..              ...
# 486       No Parent
# 487       No Parent
# 488       No Parent
# 489       No Parent
# 490       No Parent
#
# [491 rows x 21 columns]

# %%
df1.to_csv("project_Data_modified.csv", index=False)

# %%
df1
# Out:
#     sprintId           sprintName              projectName sprintStartDate  \
# 0      1,426         EPP Sprint 9  Eurisko Platform Portal       8/14/2023
# 1      1,426         EPP Sprint 9  Eurisko Platform Portal       8/14/2023
# 2      1,426         EPP Sprint 9  Eurisko Platform Portal       8/14/2023
# 3      1,426         EPP Sprint 9  Eurisko Platform Portal       8/14/2023
# 4      1,426         EPP Sprint 9  Eurisko Platform Portal       8/14/2023
# ..       ...                  ...                      ...             ...
# 486    1,363  HIVERSE - Sprint 77                  Hiverse       6/21/2023
# 487    1,363  HIVERSE - Sprint 77                  Hiverse       6/21/2023
# 488    1,363  HIVERSE - Sprint 77                  Hiverse       6/21/2023
# 489    1,363  HIVERSE - Sprint 77                  Hiverse       6/21/2023
# 490    1,363  HIVERSE - Sprint 77                  Hiverse       6/21/2023
#
#     sprintEndDate  storyPoints  sprintDurationPassed  sprintDurationEstimated  \
# 0       8/21/2023           13                612001                   604800
# 1       8/21/2023            8                612001                   604800
# 2       8/21/2023           13                626402                   604800
# 3       8/21/2023           13                626402                   604800
# 4       8/21/2023           13                626402                   604800
# ..            ...          ...                   ...                      ...
# 486      7/5/2023            0               5864405                  1209600
# 487      7/5/2023            0               5864405                  1209600
# 488      7/5/2023            0               5864405                  1209600
# 489      7/5/2023            0               5864405                  1209600
# 490      7/5/2023            0               5864405                  1209600
#
#     parentKey parentId  ...      storyKey isSubTask  storyType timeSpent  \
# 0           -        -  ...       EPP-111     False      Story         0
# 1           -        -  ...       EPP-138     False       Task         0
# 2           -        -  ...       EPP-107     False      Story     7,200
# 3           -        -  ...       EPP-134     False      Story         0
# 4           -        -  ...       EPP-133     False      Story    50,400
# ..        ...      ...  ...           ...       ...        ...       ...
# 486         -        -  ...  HIVERSE-9512     False        Bug         0
# 487         -        -  ...  HIVERSE-9526     False        Bug       600
# 488         -        -  ...  HIVERSE-9551     False        Bug         0
# 489         -        -  ...  HIVERSE-9777     False        Bug       600
# 490         -        -  ...  HIVERSE-9778     False        Bug         0
#
#     storyStatus storystatus(list) sprintDurationEstimated(in hours)  \
# 0         To Do          not done                             168.0
# 1         To Do          not done                             168.0
# 2          Done              done                             168.0
# 3          Done              done                             168.0
# 4          Done              done                             168.0
# ..          ...               ...                               ...
# 486        Done              done                             336.0
# 487        Done              done                             336.0
# 488        Done              done                             336.0
# 489        Done              done                             336.0
# 490        Done              done                             336.0
#
#      sprintDurationPassed(in hours)  sprintDurationDifference(in hours)  \
# 0                        170.000278                            2.000278
# 1                        170.000278                            2.000278
# 2                        174.000556                            6.000556
# 3                        174.000556                            6.000556
# 4                        174.000556                            6.000556
# ..                              ...                                 ...
# 486                     1629.001389                         1293.001389
# 487                     1629.001389                         1293.001389
# 488                     1629.001389                         1293.001389
# 489                     1629.001389                         1293.001389
# 490                     1629.001389                         1293.001389
#
#      parentId(List)
# 0         No Parent
# 1         No Parent
# 2         No Parent
# 3         No Parent
# 4         No Parent
# ..              ...
# 486       No Parent
# 487       No Parent
# 488       No Parent
# 489       No Parent
# 490       No Parent
#
# [491 rows x 21 columns]

# %%
df1
# Out:
#     sprintId           sprintName              projectName sprintStartDate  \
# 0      1,426         EPP Sprint 9  Eurisko Platform Portal       8/14/2023
# 1      1,426         EPP Sprint 9  Eurisko Platform Portal       8/14/2023
# 2      1,426         EPP Sprint 9  Eurisko Platform Portal       8/14/2023
# 3      1,426         EPP Sprint 9  Eurisko Platform Portal       8/14/2023
# 4      1,426         EPP Sprint 9  Eurisko Platform Portal       8/14/2023
# ..       ...                  ...                      ...             ...
# 486    1,363  HIVERSE - Sprint 77                  Hiverse       6/21/2023
# 487    1,363  HIVERSE - Sprint 77                  Hiverse       6/21/2023
# 488    1,363  HIVERSE - Sprint 77                  Hiverse       6/21/2023
# 489    1,363  HIVERSE - Sprint 77                  Hiverse       6/21/2023
# 490    1,363  HIVERSE - Sprint 77                  Hiverse       6/21/2023
#
#     sprintEndDate  storyPoints  sprintDurationPassed  sprintDurationEstimated  \
# 0       8/21/2023           13                612001                   604800
# 1       8/21/2023            8                612001                   604800
# 2       8/21/2023           13                626402                   604800
# 3       8/21/2023           13                626402                   604800
# 4       8/21/2023           13                626402                   604800
# ..            ...          ...                   ...                      ...
# 486      7/5/2023            0               5864405                  1209600
# 487      7/5/2023            0               5864405                  1209600
# 488      7/5/2023            0               5864405                  1209600
# 489      7/5/2023            0               5864405                  1209600
# 490      7/5/2023            0               5864405                  1209600
#
#     parentKey parentId  ...      storyKey isSubTask  storyType timeSpent  \
# 0           -        -  ...       EPP-111     False      Story         0
# 1           -        -  ...       EPP-138     False       Task         0
# 2           -        -  ...       EPP-107     False      Story     7,200
# 3           -        -  ...       EPP-134     False      Story         0
# 4           -        -  ...       EPP-133     False      Story    50,400
# ..        ...      ...  ...           ...       ...        ...       ...
# 486         -        -  ...  HIVERSE-9512     False        Bug         0
# 487         -        -  ...  HIVERSE-9526     False        Bug       600
# 488         -        -  ...  HIVERSE-9551     False        Bug         0
# 489         -        -  ...  HIVERSE-9777     False        Bug       600
# 490         -        -  ...  HIVERSE-9778     False        Bug         0
#
#     storyStatus storystatus(list) sprintDurationEstimated(in hours)  \
# 0         To Do          not done                             168.0
# 1         To Do          not done                             168.0
# 2          Done              done                             168.0
# 3          Done              done                             168.0
# 4          Done              done                             168.0
# ..          ...               ...                               ...
# 486        Done              done                             336.0
# 487        Done              done                             336.0
# 488        Done              done                             336.0
# 489        Done              done                             336.0
# 490        Done              done                             336.0
#
#      sprintDurationPassed(in hours)  sprintDurationDifference(in hours)  \
# 0                        170.000278                            2.000278
# 1                        170.000278                            2.000278
# 2                        174.000556                            6.000556
# 3                        174.000556                            6.000556
# 4                        174.000556                            6.000556
# ..                              ...                                 ...
# 486                     1629.001389                         1293.001389
# 487                     1629.001389                         1293.001389
# 488                     1629.001389                         1293.001389
# 489                     1629.001389                         1293.001389
# 490                     1629.001389                         1293.001389
#
#      parentId(List)
# 0         No Parent
# 1         No Parent
# 2         No Parent
# 3         No Parent
# 4         No Parent
# ..              ...
# 486       No Parent
# 487       No Parent
# 488       No Parent
# 489       No Parent
# 490       No Parent
#
# [491 rows x 21 columns]

# %%
sprint_df = df1[['sprintName']].copy()

# %%
df1
# Out:
#     sprintId           sprintName              projectName sprintStartDate  \
# 0      1,426         EPP Sprint 9  Eurisko Platform Portal       8/14/2023
# 1      1,426         EPP Sprint 9  Eurisko Platform Portal       8/14/2023
# 2      1,426         EPP Sprint 9  Eurisko Platform Portal       8/14/2023
# 3      1,426         EPP Sprint 9  Eurisko Platform Portal       8/14/2023
# 4      1,426         EPP Sprint 9  Eurisko Platform Portal       8/14/2023
# ..       ...                  ...                      ...             ...
# 486    1,363  HIVERSE - Sprint 77                  Hiverse       6/21/2023
# 487    1,363  HIVERSE - Sprint 77                  Hiverse       6/21/2023
# 488    1,363  HIVERSE - Sprint 77                  Hiverse       6/21/2023
# 489    1,363  HIVERSE - Sprint 77                  Hiverse       6/21/2023
# 490    1,363  HIVERSE - Sprint 77                  Hiverse       6/21/2023
#
#     sprintEndDate  storyPoints  sprintDurationPassed  sprintDurationEstimated  \
# 0       8/21/2023           13                612001                   604800
# 1       8/21/2023            8                612001                   604800
# 2       8/21/2023           13                626402                   604800
# 3       8/21/2023           13                626402                   604800
# 4       8/21/2023           13                626402                   604800
# ..            ...          ...                   ...                      ...
# 486      7/5/2023            0               5864405                  1209600
# 487      7/5/2023            0               5864405                  1209600
# 488      7/5/2023            0               5864405                  1209600
# 489      7/5/2023            0               5864405                  1209600
# 490      7/5/2023            0               5864405                  1209600
#
#     parentKey parentId  ...      storyKey isSubTask  storyType timeSpent  \
# 0           -        -  ...       EPP-111     False      Story         0
# 1           -        -  ...       EPP-138     False       Task         0
# 2           -        -  ...       EPP-107     False      Story     7,200
# 3           -        -  ...       EPP-134     False      Story         0
# 4           -        -  ...       EPP-133     False      Story    50,400
# ..        ...      ...  ...           ...       ...        ...       ...
# 486         -        -  ...  HIVERSE-9512     False        Bug         0
# 487         -        -  ...  HIVERSE-9526     False        Bug       600
# 488         -        -  ...  HIVERSE-9551     False        Bug         0
# 489         -        -  ...  HIVERSE-9777     False        Bug       600
# 490         -        -  ...  HIVERSE-9778     False        Bug         0
#
#     storyStatus storystatus(list) sprintDurationEstimated(in hours)  \
# 0         To Do          not done                             168.0
# 1         To Do          not done                             168.0
# 2          Done              done                             168.0
# 3          Done              done                             168.0
# 4          Done              done                             168.0
# ..          ...               ...                               ...
# 486        Done              done                             336.0
# 487        Done              done                             336.0
# 488        Done              done                             336.0
# 489        Done              done                             336.0
# 490        Done              done                             336.0
#
#      sprintDurationPassed(in hours)  sprintDurationDifference(in hours)  \
# 0                        170.000278                            2.000278
# 1                        170.000278                            2.000278
# 2                        174.000556                            6.000556
# 3                        174.000556                            6.000556
# 4                        174.000556                            6.000556
# ..                              ...                                 ...
# 486                     1629.001389                         1293.001389
# 487                     1629.001389                         1293.001389
# 488                     1629.001389                         1293.001389
# 489                     1629.001389                         1293.001389
# 490                     1629.001389                         1293.001389
#
#      parentId(List)
# 0         No Parent
# 1         No Parent
# 2         No Parent
# 3         No Parent
# 4         No Parent
# ..              ...
# 486       No Parent
# 487       No Parent
# 488       No Parent
# 489       No Parent
# 490       No Parent
#
# [491 rows x 21 columns]

# %%
df1.columns
# Out:
# Index(['sprintId', 'sprintName', 'projectName', 'sprintStartDate',
#        'sprintEndDate', 'storyPoints', 'sprintDurationPassed',
#        'sprintDurationEstimated', 'parentKey', 'parentId', 'sprintStatus',
#        'storyKey', 'isSubTask', 'storyType', 'timeSpent', 'storyStatus',
#        'storystatus(list)', 'sprintDurationEstimated(in hours)',
#        'sprintDurationPassed(in hours)', 'sprintDurationDifference(in hours)',
#        'parentId(List)'],
#       dtype='object')

# %%
df1.info
# Out:
# <bound method DataFrame.info of     sprintId           sprintName              projectName sprintStartDate  \
# 0      1,426         EPP Sprint 9  Eurisko Platform Portal       8/14/2023
# 1      1,426         EPP Sprint 9  Eurisko Platform Portal       8/14/2023
# 2      1,426         EPP Sprint 9  Eurisko Platform Portal       8/14/2023
# 3      1,426         EPP Sprint 9  Eurisko Platform Portal       8/14/2023
# 4      1,426         EPP Sprint 9  Eurisko Platform Portal       8/14/2023
# ..       ...                  ...                      ...             ...
# 486    1,363  HIVERSE - Sprint 77                  Hiverse       6/21/2023
# 487    1,363  HIVERSE - Sprint 77                  Hiverse       6/21/2023
# 488    1,363  HIVERSE - Sprint 77                  Hiverse       6/21/2023
# 489    1,363  HIVERSE - Sprint 77                  Hiverse       6/21/2023
# 490    1,363  HIVERSE - Sprint 77                  Hiverse       6/21/2023
#
#     sprintEndDate  storyPoints  sprintDurationPassed  sprintDurationEstimated  \
# 0       8/21/2023           13                612001                   604800
# 1       8/21/2023            8                612001                   604800
# 2       8/21/2023           13                626402                   604800
# 3       8/21/2023           13                626402                   604800
# 4       8/21/2023           13                626402                   604800
# ..            ...          ...                   ...                      ...
# 486      7/5/2023            0               5864405                  1209600
# 487      7/5/2023            0               5864405                  1209600
# 488      7/5/2023            0               5864405                  1209600
# 489      7/5/2023            0               5864405                  1209600
# 490      7/5/2023            0               5864405                  1209600
#
#     parentKey parentId  ...      storyKey isSubTask  storyType timeSpent  \
# 0           -        -  ...       EPP-111     False      Story         0
# 1           -        -  ...       EPP-138     False       Task         0
# 2           -        -  ...       EPP-107     False      Story     7,200
# 3           -        -  ...       EPP-134     False      Story         0
# 4           -        -  ...       EPP-133     False      Story    50,400
# ..        ...      ...  ...           ...       ...        ...       ...
# 486         -        -  ...  HIVERSE-9512     False        Bug         0
# 487         -        -  ...  HIVERSE-9526     False        Bug       600
# 488         -        -  ...  HIVERSE-9551     False        Bug         0
# 489         -        -  ...  HIVERSE-9777     False        Bug       600
# 490         -        -  ...  HIVERSE-9778     False        Bug         0
#
#     storyStatus storystatus(list) sprintDurationEstimated(in hours)  \
# 0         To Do          not done                             168.0
# 1         To Do          not done                             168.0
# 2          Done              done                             168.0
# 3          Done              done                             168.0
# 4          Done              done                             168.0
# ..          ...               ...                               ...
# 486        Done              done                             336.0
# 487        Done              done                             336.0
# 488        Done              done                             336.0
# 489        Done              done                             336.0
# 490        Done              done                             336.0
#
#      sprintDurationPassed(in hours)  sprintDurationDifference(in hours)  \
# 0                        170.000278                            2.000278
# 1                        170.000278                            2.000278
# 2                        174.000556                            6.000556
# 3                        174.000556                            6.000556
# 4                        174.000556                            6.000556
# ..                              ...                                 ...
# 486                     1629.001389                         1293.001389
# 487                     1629.001389                         1293.001389
# 488                     1629.001389                         1293.001389
# 489                     1629.001389                         1293.001389
# 490                     1629.001389                         1293.001389
#
#      parentId(List)
# 0         No Parent
# 1         No Parent
# 2         No Parent
# 3         No Parent
# 4         No Parent
# ..              ...
# 486       No Parent
# 487       No Parent
# 488       No Parent
# 489       No Parent
# 490       No Parent
#
# [491 rows x 21 columns]>

# %%
df1
# Out:
#     sprintId           sprintName              projectName sprintStartDate  \
# 0      1,426         EPP Sprint 9  Eurisko Platform Portal       8/14/2023
# 1      1,426         EPP Sprint 9  Eurisko Platform Portal       8/14/2023
# 2      1,426         EPP Sprint 9  Eurisko Platform Portal       8/14/2023
# 3      1,426         EPP Sprint 9  Eurisko Platform Portal       8/14/2023
# 4      1,426         EPP Sprint 9  Eurisko Platform Portal       8/14/2023
# ..       ...                  ...                      ...             ...
# 486    1,363  HIVERSE - Sprint 77                  Hiverse       6/21/2023
# 487    1,363  HIVERSE - Sprint 77                  Hiverse       6/21/2023
# 488    1,363  HIVERSE - Sprint 77                  Hiverse       6/21/2023
# 489    1,363  HIVERSE - Sprint 77                  Hiverse       6/21/2023
# 490    1,363  HIVERSE - Sprint 77                  Hiverse       6/21/2023
#
#     sprintEndDate  storyPoints  sprintDurationPassed  sprintDurationEstimated  \
# 0       8/21/2023           13                612001                   604800
# 1       8/21/2023            8                612001                   604800
# 2       8/21/2023           13                626402                   604800
# 3       8/21/2023           13                626402                   604800
# 4       8/21/2023           13                626402                   604800
# ..            ...          ...                   ...                      ...
# 486      7/5/2023            0               5864405                  1209600
# 487      7/5/2023            0               5864405                  1209600
# 488      7/5/2023            0               5864405                  1209600
# 489      7/5/2023            0               5864405                  1209600
# 490      7/5/2023            0               5864405                  1209600
#
#     parentKey parentId  ...      storyKey isSubTask  storyType timeSpent  \
# 0           -        -  ...       EPP-111     False      Story         0
# 1           -        -  ...       EPP-138     False       Task         0
# 2           -        -  ...       EPP-107     False      Story     7,200
# 3           -        -  ...       EPP-134     False      Story         0
# 4           -        -  ...       EPP-133     False      Story    50,400
# ..        ...      ...  ...           ...       ...        ...       ...
# 486         -        -  ...  HIVERSE-9512     False        Bug         0
# 487         -        -  ...  HIVERSE-9526     False        Bug       600
# 488         -        -  ...  HIVERSE-9551     False        Bug         0
# 489         -        -  ...  HIVERSE-9777     False        Bug       600
# 490         -        -  ...  HIVERSE-9778     False        Bug         0
#
#     storyStatus storystatus(list) sprintDurationEstimated(in hours)  \
# 0         To Do          not done                             168.0
# 1         To Do          not done                             168.0
# 2          Done              done                             168.0
# 3          Done              done                             168.0
# 4          Done              done                             168.0
# ..          ...               ...                               ...
# 486        Done              done                             336.0
# 487        Done              done                             336.0
# 488        Done              done                             336.0
# 489        Done              done                             336.0
# 490        Done              done                             336.0
#
#      sprintDurationPassed(in hours)  sprintDurationDifference(in hours)  \
# 0                        170.000278                            2.000278
# 1                        170.000278                            2.000278
# 2                        174.000556                            6.000556
# 3                        174.000556                            6.000556
# 4                        174.000556                            6.000556
# ..                              ...                                 ...
# 486                     1629.001389                         1293.001389
# 487                     1629.001389                         1293.001389
# 488                     1629.001389                         1293.001389
# 489                     1629.001389                         1293.001389
# 490                     1629.001389                         1293.001389
#
#      parentId(List)
# 0         No Parent
# 1         No Parent
# 2         No Parent
# 3         No Parent
# 4         No Parent
# ..              ...
# 486       No Parent
# 487       No Parent
# 488       No Parent
# 489       No Parent
# 490       No Parent
#
# [491 rows x 21 columns]
