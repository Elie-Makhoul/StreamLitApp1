# %%
import pandas as pd
df = pd.read_csv(
    "C:\\Users\\pc\\Desktop\\Data science & AI\\Python\\csv\\Project_Data.csv")

df
# Out:
#     sprintId   sprintName.keyword      projectName.keyword sprintStartDate  \
# 0      1,426         EPP Sprint 9  Eurisko Platform Portal       8/14/2023
# 1      1,426         EPP Sprint 9  Eurisko Platform Portal       8/14/2023
# 2      1,426         EPP Sprint 9  Eurisko Platform Portal       8/14/2023
# 3      1,426         EPP Sprint 9  Eurisko Platform Portal       8/14/2023
# 4      1,426         EPP Sprint 9  Eurisko Platform Portal       8/14/2023
# ..       ...                  ...                      ...             ...
# 486    1,363  HIVERSE - Sprint 77                  Hiverse       6/21/2023
# 487    1,363  HIVERSE - Sprint 77                  Hiverse       6/21/2023
# 488    1,363  HIVERSE - Sprint 77                  Hiverse       6/21/2023
# 489    1,363  HIVERSE - Sprint 77                  Hiverse       6/21/2023
# 490    1,363  HIVERSE - Sprint 77                  Hiverse       6/21/2023
#
# ...

# %%
df.drop({'projectName',"sprintName","storyKey.keyword" }, axis=1, inplace=True)

# %%
df
# Out:
#     sprintId   sprintName.keyword      projectName.keyword sprintStartDate  \
# 0      1,426         EPP Sprint 9  Eurisko Platform Portal       8/14/2023
# 1      1,426         EPP Sprint 9  Eurisko Platform Portal       8/14/2023
# 2      1,426         EPP Sprint 9  Eurisko Platform Portal       8/14/2023
# 3      1,426         EPP Sprint 9  Eurisko Platform Portal       8/14/2023
# 4      1,426         EPP Sprint 9  Eurisko Platform Portal       8/14/2023
# ..       ...                  ...                      ...             ...
# 486    1,363  HIVERSE - Sprint 77                  Hiverse       6/21/2023
# 487    1,363  HIVERSE - Sprint 77                  Hiverse       6/21/2023
# 488    1,363  HIVERSE - Sprint 77                  Hiverse       6/21/2023
# 489    1,363  HIVERSE - Sprint 77                  Hiverse       6/21/2023
# 490    1,363  HIVERSE - Sprint 77                  Hiverse       6/21/2023
#
# ...

# %%
df.rename(columns={'sprintName.keyword': 'sprintName', 'projectName.keyword': 'projectName'}, inplace=True)

# %%
df
# Out:
#     sprintId           sprintName              projectName sprintStartDate  \
# 0      1,426         EPP Sprint 9  Eurisko Platform Portal       8/14/2023
# 1      1,426         EPP Sprint 9  Eurisko Platform Portal       8/14/2023
# 2      1,426         EPP Sprint 9  Eurisko Platform Portal       8/14/2023
# 3      1,426         EPP Sprint 9  Eurisko Platform Portal       8/14/2023
# 4      1,426         EPP Sprint 9  Eurisko Platform Portal       8/14/2023
# ..       ...                  ...                      ...             ...
# 486    1,363  HIVERSE - Sprint 77                  Hiverse       6/21/2023
# 487    1,363  HIVERSE - Sprint 77                  Hiverse       6/21/2023
# 488    1,363  HIVERSE - Sprint 77                  Hiverse       6/21/2023
# 489    1,363  HIVERSE - Sprint 77                  Hiverse       6/21/2023
# 490    1,363  HIVERSE - Sprint 77                  Hiverse       6/21/2023
#
# ...

# %%
df1 = pd.to_datetime(df['date_column'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\pc\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexes\base.py:3790, in Index.get_loc(self, key)
#    3789 try:
# -> 3790     return self._engine.get_loc(casted_key)
#    3791 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:181, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'date_column'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
df1 = df.copy()

# %%
df1
# Out:
#     sprintId           sprintName              projectName sprintStartDate  \
# 0      1,426         EPP Sprint 9  Eurisko Platform Portal       8/14/2023
# 1      1,426         EPP Sprint 9  Eurisko Platform Portal       8/14/2023
# 2      1,426         EPP Sprint 9  Eurisko Platform Portal       8/14/2023
# 3      1,426         EPP Sprint 9  Eurisko Platform Portal       8/14/2023
# 4      1,426         EPP Sprint 9  Eurisko Platform Portal       8/14/2023
# ..       ...                  ...                      ...             ...
# 486    1,363  HIVERSE - Sprint 77                  Hiverse       6/21/2023
# 487    1,363  HIVERSE - Sprint 77                  Hiverse       6/21/2023
# 488    1,363  HIVERSE - Sprint 77                  Hiverse       6/21/2023
# 489    1,363  HIVERSE - Sprint 77                  Hiverse       6/21/2023
# 490    1,363  HIVERSE - Sprint 77                  Hiverse       6/21/2023
#
# ...

# %%
df1["sprintStartDate"] = pd.to_datetime(df1['sprintStartDate'])

# %%
df1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\pc\Desktop\Data science & AI\Python\Jupyter notebook\project.ipynb Cell 10 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/pc/Desktop/Data%20science%20%26%20AI/Python/Jupyter%20notebook/project.ipynb#X12sZmlsZQ%3D%3D?line=0'>1</a> df1
#
# NameError: name 'df1' is not defined

# %%
df
# Out:
#     sprintId           sprintName              projectName sprintStartDate  \
# 0      1,426         EPP Sprint 9  Eurisko Platform Portal       8/14/2023
# 1      1,426         EPP Sprint 9  Eurisko Platform Portal       8/14/2023
# 2      1,426         EPP Sprint 9  Eurisko Platform Portal       8/14/2023
# 3      1,426         EPP Sprint 9  Eurisko Platform Portal       8/14/2023
# 4      1,426         EPP Sprint 9  Eurisko Platform Portal       8/14/2023
# ..       ...                  ...                      ...             ...
# 486    1,363  HIVERSE - Sprint 77                  Hiverse       6/21/2023
# 487    1,363  HIVERSE - Sprint 77                  Hiverse       6/21/2023
# 488    1,363  HIVERSE - Sprint 77                  Hiverse       6/21/2023
# 489    1,363  HIVERSE - Sprint 77                  Hiverse       6/21/2023
# 490    1,363  HIVERSE - Sprint 77                  Hiverse       6/21/2023
#
# ...

# %%
df1["sprintEndDate"] = pd.to_datetime(df1['sprintEndDate'])

# %%
df1

# %%
df1["sprintDuration"] = df1["sprintEndDate"] - df1["sprintStartDate"]

# %%
df1

# %%
def group_status(status):
    if status.lower() == 'done':
        return 'done'
    else:
        return 'not done'

# %%
def group_status(status):
    if status.lower() == 'done':
        return 'done'
    else:
        return 'not done'
    
df1['storystatus(group)'] = df1['story_status'].apply(group_status)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\pc\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexes\base.py:3790, in Index.get_loc(self, key)
#    3789 try:
# -> 3790     return self._engine.get_loc(casted_key)
#    3791 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:219, in pandas._libs.index.IndexEngine._get_loc_duplicates()
#
# File index.pyx:227, in pandas._libs.index.IndexEngine._maybe_get_bool_indexer()
#
# File index.pyx:119, in pandas._libs.index._unpack_bool_indexer()
#
# KeyError: 'story_status'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
def group_status(status):
    if status.lower() == 'done':
        return 'done'
    else:
        return 'not done'
    
df1['storystatus(group)'] = df1["storyStatus"].apply(group_status)

# %%
df1

# %%
df1.loc(14)

# %%
df1[df1['storyKey'] == "HIVERSE-9329"]
# Out:
#     sprintId           sprintName projectName sprintStartDate sprintEndDate  \
# 236    1,393  HIVERSE - Sprint 78     Hiverse      2023-07-18    2023-07-25
#
#      storyPoints storyKey.keyword sprintDurationPassed  \
# 236            0     HIVERSE-9329            3,604,202
#
#     sprintDurationEstimated parentKey  ... projectName           sprintName  \
# 236                 541,200         -  ...     Hiverse  HIVERSE - Sprint 78
#
#     sprintStatus      storyKey isSubTask  storyType timeSpent  storyStatus  \
# 236       active  HIVERSE-9329     False        Bug         0  Q.A Testing
#
#     sprintDuration storystatus(group)
# 236         7 days           not done
#
# [1 rows x 21 columns]

# %%
df1.loc[12]

# %%
df1.loc[236]

# %%
df1

# %%
df1['sprintDurationPassed(in hours)'] = df1["sprintDurationPassed"] / 3600
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File c:\Users\pc\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\ops\array_ops.py:220, in _na_arithmetic_op(left, right, op, is_cmp)
#     219 try:
# --> 220     result = func(left, right)
#     221 except TypeError:
#
# File c:\Users\pc\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\computation\expressions.py:242, in evaluate(op, a, b, use_numexpr)
#     240     if use_numexpr:
#     241         # error: "None" not callable
# --> 242         return _evaluate(op, op_str, a, b)  # type: ignore[misc]
#     243 return _evaluate_standard(op, op_str, a, b)
#
# File c:\Users\pc\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\computation\expressions.py:73, in _evaluate_standard(op, op_str, a, b)
#      72     _store_test_result(False)
# ---> 73 return op(a, b)
#
# ...

# %%
type(df1["sprintDurationPassed"][1])
# Out:
# str

# %%
df

# %%
df1 = df.copy()

# %%
df1

# %%
def group_status(status):
    if status.lower() == 'done':
        return 'done'
    else:
        return 'not done'
    
df1['storystatus(group)'] = df1["storyStatus"].apply(group_status)

# %%
df1

# %%
df1['sprintDurationEstimated'] = df1['sprintDurationEstimated'].str.replace(',', '')

# %%
df1['sprintDurationPassed'] = df1['sprintDurationPassed'].str.replace(',', '')

# %%
df['sprintDurationEstimated'].replace('', '0', inplace=True)

# %%
df1['sprintDurationEstimated'].replace('', '0', inplace=True)

# %%
df1['sprintDurationPassed'].replace('', '0', inplace=True)

# %%
df1

# %%
df1['sprintDurationPassed'].replace('-', '0', inplace=True)

# %%
df1['sprintDurationEstimated'].replace('-', '0', inplace=True)

# %%
df1['sprintDurationEstimated'] = df['sprintDurationEstimated'].astype(int)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\Users\pc\Desktop\Data science & AI\Python\Jupyter notebook\project.ipynb Cell 41 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/pc/Desktop/Data%20science%20%26%20AI/Python/Jupyter%20notebook/project.ipynb#X55sZmlsZQ%3D%3D?line=0'>1</a> df1['sprintDurationEstimated'] = df['sprintDurationEstimated'].astype(int)
#
# File c:\Users\pc\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\generic.py:6532, in NDFrame.astype(self, dtype, copy, errors)
#    6528     results = [ser.astype(dtype, copy=copy) for _, ser in self.items()]
#    6530 else:
#    6531     # else, only a single dtype is given
# -> 6532     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6533     res = self._constructor_from_mgr(new_data, axes=new_data.axes)
# ...

# %%
df1['sprintDurationEstimated'] = df1['sprintDurationEstimated'].astype(int)

# %%
df1['sprintDurationPassed'] = df1['sprintDurationPassed'].astype(int)

# %%
df1
# Out:
#     sprintId           sprintName              projectName sprintStartDate  \
# 0      1,426         EPP Sprint 9  Eurisko Platform Portal      2023-08-14
# 1      1,426         EPP Sprint 9  Eurisko Platform Portal      2023-08-14
# 2      1,426         EPP Sprint 9  Eurisko Platform Portal      2023-08-14
# 3      1,426         EPP Sprint 9  Eurisko Platform Portal      2023-08-14
# 4      1,426         EPP Sprint 9  Eurisko Platform Portal      2023-08-14
# ..       ...                  ...                      ...             ...
# 486    1,363  HIVERSE - Sprint 77                  Hiverse      2023-06-21
# 487    1,363  HIVERSE - Sprint 77                  Hiverse      2023-06-21
# 488    1,363  HIVERSE - Sprint 77                  Hiverse      2023-06-21
# 489    1,363  HIVERSE - Sprint 77                  Hiverse      2023-06-21
# 490    1,363  HIVERSE - Sprint 77                  Hiverse      2023-06-21
#
# ...

# %%
type(df1["sprintDurationPassed"][1])
# Out:
# numpy.int32

# %%
df1["sprintDurationEstimated(in hours)"] = df1["sprintDurationEstimated"] / 3600

# %%
df1["sprintDurationPasses(in hours)"] = df1["sprintDurationPassed"] / 3600

# %%
df1 = df1.rename(columns={'sprintDurationPasses(in hours)': 'sprintDurationPassed(in hours)'})
df1
# Out:
#     sprintId           sprintName              projectName sprintStartDate  \
# 0      1,426         EPP Sprint 9  Eurisko Platform Portal      2023-08-14
# 1      1,426         EPP Sprint 9  Eurisko Platform Portal      2023-08-14
# 2      1,426         EPP Sprint 9  Eurisko Platform Portal      2023-08-14
# 3      1,426         EPP Sprint 9  Eurisko Platform Portal      2023-08-14
# 4      1,426         EPP Sprint 9  Eurisko Platform Portal      2023-08-14
# ..       ...                  ...                      ...             ...
# 486    1,363  HIVERSE - Sprint 77                  Hiverse      2023-06-21
# 487    1,363  HIVERSE - Sprint 77                  Hiverse      2023-06-21
# 488    1,363  HIVERSE - Sprint 77                  Hiverse      2023-06-21
# 489    1,363  HIVERSE - Sprint 77                  Hiverse      2023-06-21
# 490    1,363  HIVERSE - Sprint 77                  Hiverse      2023-06-21
#
# ...

# %%
df1 = df1.rename(columns={'storystatus(group)': 'storystatus(list)'})

# %%
df1
# Out:
#     sprintId           sprintName              projectName sprintStartDate  \
# 0      1,426         EPP Sprint 9  Eurisko Platform Portal      2023-08-14
# 1      1,426         EPP Sprint 9  Eurisko Platform Portal      2023-08-14
# 2      1,426         EPP Sprint 9  Eurisko Platform Portal      2023-08-14
# 3      1,426         EPP Sprint 9  Eurisko Platform Portal      2023-08-14
# 4      1,426         EPP Sprint 9  Eurisko Platform Portal      2023-08-14
# ..       ...                  ...                      ...             ...
# 486    1,363  HIVERSE - Sprint 77                  Hiverse      2023-06-21
# 487    1,363  HIVERSE - Sprint 77                  Hiverse      2023-06-21
# 488    1,363  HIVERSE - Sprint 77                  Hiverse      2023-06-21
# 489    1,363  HIVERSE - Sprint 77                  Hiverse      2023-06-21
# 490    1,363  HIVERSE - Sprint 77                  Hiverse      2023-06-21
#
# ...

# %%
df1 = df1.rename(columns={'sprintDurationPasses(in hours)': 'sprintDurationPassed(in hours)'})

# %%
df1["sprintDurationDifference(in hours)"] = df1["sprintDurationPassed(in hours)"] - df1["sprintDurationEstimated(in hours)"]

# %%
(df1["storyType"] == "sub Task")

# %%
def group_parent_id(row):
    if row['isSubTask']:
        return 'contains Parent'
    else:
        return 'No Parent'
    
df1['parentId(List)'] = df1.apply(group_parent_id, axis=1)

# %%
df1
# Out:
#     sprintId           sprintName              projectName sprintStartDate  \
# 0      1,426         EPP Sprint 9  Eurisko Platform Portal      2023-08-14
# 1      1,426         EPP Sprint 9  Eurisko Platform Portal      2023-08-14
# 2      1,426         EPP Sprint 9  Eurisko Platform Portal      2023-08-14
# 3      1,426         EPP Sprint 9  Eurisko Platform Portal      2023-08-14
# 4      1,426         EPP Sprint 9  Eurisko Platform Portal      2023-08-14
# ..       ...                  ...                      ...             ...
# 486    1,363  HIVERSE - Sprint 77                  Hiverse      2023-06-21
# 487    1,363  HIVERSE - Sprint 77                  Hiverse      2023-06-21
# 488    1,363  HIVERSE - Sprint 77                  Hiverse      2023-06-21
# 489    1,363  HIVERSE - Sprint 77                  Hiverse      2023-06-21
# 490    1,363  HIVERSE - Sprint 77                  Hiverse      2023-06-21
#
# ...

# %%
df

# %%
df1

# %%
df1.to_csv("project_Data_modified.csv", index=False)

# %%
df1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\pc\Desktop\Data science & AI\Python\Jupyter notebook\project.ipynb Cell 58 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/pc/Desktop/Data%20science%20%26%20AI/Python/Jupyter%20notebook/project.ipynb#Y111sZmlsZQ%3D%3D?line=0'>1</a> df1
#
# NameError: name 'df1' is not defined

# %%
df1
# Out:
#     sprintId           sprintName              projectName sprintStartDate  \
# 0      1,426         EPP Sprint 9  Eurisko Platform Portal      2023-08-14
# 1      1,426         EPP Sprint 9  Eurisko Platform Portal      2023-08-14
# 2      1,426         EPP Sprint 9  Eurisko Platform Portal      2023-08-14
# 3      1,426         EPP Sprint 9  Eurisko Platform Portal      2023-08-14
# 4      1,426         EPP Sprint 9  Eurisko Platform Portal      2023-08-14
# ..       ...                  ...                      ...             ...
# 486    1,363  HIVERSE - Sprint 77                  Hiverse      2023-06-21
# 487    1,363  HIVERSE - Sprint 77                  Hiverse      2023-06-21
# 488    1,363  HIVERSE - Sprint 77                  Hiverse      2023-06-21
# 489    1,363  HIVERSE - Sprint 77                  Hiverse      2023-06-21
# 490    1,363  HIVERSE - Sprint 77                  Hiverse      2023-06-21
#
# ...
